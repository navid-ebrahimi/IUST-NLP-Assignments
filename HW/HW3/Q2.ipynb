# %% [markdown]
# # Q2

# %% [markdown]
# *   In this question we will Build a bigram HMM tagger.
# *   First we split the part-of-speech-tagged corpus into a training set and test set.
# *   From the labeled training set, we train the transition and observation probabilities of the HMM tagger directly on the hand-tagged data.
# *   Then implement the Viterbi algorithm so we can decode a test sentence.
# *   Run the algorithm on the test set. Report its error rate and
# compare its performance to the most frequent tag baseline.
# *   Build a confusion matrix and investigate the most frequent errors.

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
import math
import nltk
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
def collect_probabilities(_samples):
    """
    Collects various probabilities and frequencies required for Hidden Markov Model (HMM) training based on given samples.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing training data.

    Returns:
    tuple: A tuple containing four dictionaries:
           - tag_freq: A dictionary storing the frequency of each tag type.
           - word_per_tag_freq: A nested dictionary storing the frequency of each word under each tag.
           - bigram: A nested dictionary representing the bigram probabilities between tag types.
           - pi: A dictionary storing the initial probability distributions for tag types.

    Comments:
    - tag_freq: Stores the frequency of each tag type observed in the training data.
    - word_per_tag_freq: Stores the frequency of each word observed under each tag in the training data.
      - Each word under a specific tag is initialized with a count of 2 to provide initial smoothing.
    - bigram: Represents the transition probabilities between tag types based on bigram counts.
    - pi: Stores the initial probability distributions for tag types based on the second tag in each sample.
    """
    tag_freq = {}
    word_per_tag_freq = {}
    bigram = {}
    pi = {}
    samples_len = len(_samples)

    # Iterate through samples to collect tag frequencies, word frequencies under each tag, and initial probabilities
    for i in range(samples_len):
        sample = _samples[i]
        has_next = i + 1 < samples_len

        # Collect data for initial probabilities (pi)
        if has_next:
            if _samples[i + 1][1] not in pi:
                pi.update({_samples[i + 1][1]: 2})
            else:
               pi[_samples[i + 1][1]] += 1

        # Count tag frequencies (tag_freq) and word frequencies under each tag (word_per_tag_freq)
        if sample[1] not in tag_freq:
            tag_freq.update({sample[1]: 2})
            word_per_tag_freq.update({sample[1]: {sample[0]: 2}})
        else:
            tag_freq[sample[1]] += 1
            if sample[0] not in word_per_tag_freq[sample[1]]:
                word_per_tag_freq[sample[1]].update({sample[0]: 2})
            else:
                word_per_tag_freq[sample[1]][sample[0]] += 1


    # Initialize the bigram matrix with default counts
    for tag_0 in tag_freq:
        bigram.update({tag_0: {}})
        for tag_1 in tag_freq:
            bigram[tag_0].update({tag_1: 1})

    # Count bigram occurrences
    for i in range(samples_len - 1):
        if _samples[i][1] in bigram and _samples[i + 1][1] in bigram[_samples[i][1]]:
            bigram[_samples[i][1]][_samples[i + 1][1]] += 1

    # Return collected probabilities and frequencies
    return tag_freq, word_per_tag_freq, bigram, pi

# %%
def create_confusion_matrix(predictions, hidden_state, confusion_matrices , is_correct):
    """
    Updates the confusion matrices based on the predictions and hidden states,
    calculates the number of correct predictions, and identifies tags with
    the most false positives and false negatives.

    Args:
    predictions (list): Predicted sequence of tags for the given input data.
    hidden_state (list): Actual sequence of tags for the given input data.
    confusion_matrices (dict): A dictionary containing confusion matrices for each tag.
    is_correct (int): Counter for the number of correct predictions.

    Returns:
    int: Updated count of correct predictions after processing the input data.

    Comments:
    - As the Viterbi algorithm processes each sentence in the test data,
      it compares the predicted tags against the actual tags for each word in the sentence.
        - For each word in the sentence, if the predicted tag matches the actual tag (a true positive),
          the corresponding count in the confusion matrix for that tag is incremented.
        - If the predicted tag does not match the actual tag:
            - If the predicted tag is incorrect (a false positive), the FP count for
              the predicted tag is incremented, and the TN counts for other tags are incremented.
            - If the actual tag is not predicted (a false negative), the FN count for the actual
              tag is incremented, and the TN counts for other tags are incremented.
    - After updating the confusion matrices, the function identifies tags with
      the highest counts of false positives and false negatives.
    """
    # fill in the confusion matrix
    for i in range(len(predictions)):
        if predictions[i] == hidden_state[i]:
            # prediction is correct
            is_correct += 1
            for j in confusion_matrices:
                if j == predictions[i]:
                    confusion_matrices[j]['TP'] += 1
                else:
                    confusion_matrices[j]['TN'] += 1
        else:
            # prediction is incorrect
            for j in confusion_matrices:
                if j == predictions[i]:
                    confusion_matrices[j]['FP'] += 1
                elif j == hidden_state[i]:
                    confusion_matrices[j]['FN'] += 1
                else:
                    confusion_matrices[j]['TN'] += 1


    # rank
    highest_FP_tag = []
    highest_FP = -1
    highest_FN_tag = []
    highest_FN = -1

    for tag in confusion_matrices:

        print(f'{tag}: {confusion_matrices[tag]}')

        if confusion_matrices[tag]['FP'] > highest_FP:
            highest_FP = confusion_matrices[tag]['FP']
            highest_FP_tag = tag

        if confusion_matrices[tag]['FN'] > highest_FN:
            highest_FN = confusion_matrices[tag]['FN']
            highest_FN_tag = tag

    print(f'\nTag with the most false positives is: {highest_FP_tag} with {highest_FP} counts.')
    print(f'Tag with the most false negative is:  {highest_FN_tag} with {highest_FN} counts.')

    print(f'confusion_matrices: {confusion_matrices}')


    return is_correct

# %%
def viterbi(_samples, _tag_freq, _word_per_tag_freq, _bigram, _init_dist):
    """
    Performs the Viterbi algorithm for part-of-speech tagging on a given test set of sentences.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing the test data.
    _tag_freq (dict): A dictionary storing the frequency of each tag type observed in the training data.
    _word_per_tag_freq (dict): A nested dictionary storing the frequency of each word observed under each tag in the training data.
    _bigram (dict): A nested dictionary representing the bigram probabilities between tag types.
    _init_dist (dict): A dictionary storing the initial probability distributions for tag types.

    Comments:
    - This function implements the Viterbi algorithm for part-of-speech tagging.
    - It processes each sentence in the test set, using '.' as an indicator that a sentence is over.
    - The function populates a confusion matrix to track the performance of the model.
    - The Viterbi algorithm is used to find the most likely sequence of tags for each sentence.
    - The algorithm iterates through each word in the sentence, calculating the most likely tag sequence based on probabilities and transition probabilities.
    - The model's predictions are compared against the actual tags to evaluate accuracy and populate the confusion matrix.
    - The function prints detailed information about predictions, including the sentence, hidden states, and predicted tags.
    - It also identifies tags with the most false positives and false negatives based on the confusion matrix.
    - Finally, the function prints the overall accuracy of the model on the test set.
    """
    test_size = len(_samples)
    current_index = 0
    is_correct = 0

    # populate the confusion matrix
    confusion_matrices = {}
    for tag in _tag_freq:
        confusion_matrices.update({tag: {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0}})

    while current_index < test_size:
        # find the boundry of a sentence
        sentence = []
        hidden_state = []
        last_token = ''
        while last_token != '.' and current_index < test_size:
            sentence.append(_samples[current_index][0])
            hidden_state.append(_samples[current_index][1])
            last_token = sentence[-1]
            current_index += 1

        # initialization step
        path_probability = {}
        backpointer = {}
        for tag in init_dist:
            path_probability.update({tag: []})
            backpointer.update({tag: [0]})

            # initial distribution of this tag
            pi_tag = init_dist[tag]

            # b_word is the probability of the word being generated by this tag
            if sentence[0] in _word_per_tag_freq[tag]:
                b_word = _word_per_tag_freq[tag][sentence[0]]
            else:
                b_word = 2.2250738585072014e-100
            path_probability[tag].append(math.log(pi_tag * b_word, 10))

        # recursion step
        T = len(sentence)
        for i in range(1, T):
            for tag in init_dist:

                if sentence[i] in _word_per_tag_freq[tag]:
                    b_word = _word_per_tag_freq[tag][sentence[i]]
                else:
                    b_word = 2.2250738585072014e-100

                # search the maximum value of
                # viterbi[s', t-1] * a(s|s') *b_s(o_t)
                best_trans_prob = -2.2250738585072014e+308
                best_trans_tag = ''
                for prev_tag in init_dist:
                    if prev_tag in _bigram and tag in _bigram[prev_tag]:
                        transitional_prob = _bigram[prev_tag][tag]
                    else:
                        transitional_prob = 2.2250738585072014e-100

                    prob = path_probability[prev_tag][i - 1] + math.log(transitional_prob * b_word, 10)

                    if prob > best_trans_prob:
                        best_trans_prob = prob
                        best_trans_tag = prev_tag

                path_probability[tag].append(best_trans_prob)
                backpointer[tag].append(best_trans_tag)

        # termination step
        best_path_prob = -2.2250738585072014e+308
        best_path_pointer = None
        for tag in init_dist:
            if path_probability[tag][-1] > best_path_prob:
                best_path_prob = path_probability[tag][-1]
                best_path_pointer = tag

        predictions = [best_path_pointer]

        # make the predictions path
        for i in reversed(range(1, T)):
            predictions.append(backpointer[predictions[-1]][i])

        predictions.reverse()

        print(f'sentence:       {sentence}')
        print(f'hidden s:       {hidden_state}')
        print(f'predictions:    {predictions}')

        is_correct = create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct)

    print(f'\nmodel got {is_correct} samples correct out of {test_size}')
    print(f'accuracy: {is_correct / test_size}')

    error_rate_hmm = (test_size - is_correct) / test_size
    most_frequent_tag = max(_tag_freq, key=_tag_freq.get)
    baseline_predictions = [most_frequent_tag] * len(testing_list)

    baseline_is_correct = sum(1 for i in range(len(testing_list)) if baseline_predictions[i] == testing_list[i][1])
    error_rate_baseline = (test_size - baseline_is_correct) / test_size

    print(f"Error rate for the HMM model: {error_rate_hmm}")
    print(f"Error rate for the most frequent tag baseline: {error_rate_baseline}")

# %%
CORPUS = brown.tagged_words(categories='news', tagset='universal')
CORPUS_SIZE = len(brown.tagged_words(categories='news'))

CUT_OFF = math.floor(CORPUS_SIZE * 0.75)

# section off training and testing lists from corpus
training_list = CORPUS[:CUT_OFF]
testing_list = CORPUS[CUT_OFF:]

tag_frequency, word_per_tag_frequency, tag_bigram, init_dist = collect_probabilities(training_list)
viterbi(testing_list, tag_frequency, word_per_tag_frequency, tag_bigram, init_dist)
# Out:
# Streaming output truncated to the last 5000 lines.
# predictions:    ['DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2300, 'FP': 185, 'TN': 16635, 'FN': 24}
# NOUN: {'TP': 4786, 'FP': 1152, 'TN': 13057, 'FN': 149}
# ADJ: {'TP': 963, 'FP': 89, 'TN': 17494, 'FN': 598}
# VERB: {'TP': 2198, 'FP': 101, 'TN': 16308, 'FN': 537}
# ADP: {'TP': 2354, 'FP': 479, 'TN': 16285, 'FN': 26}
# .: {'TP': 2333, 'FP': 13, 'TN': 16798, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18281, 'FN': 251}
# CONJ: {'TP': 564, 'FP': 2, 'TN': 18562, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18639, 'FN': 275}
# PRON: {'TP': 510, 'FP': 2, 'TN': 18599, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18769, 'FN': 108}
# X: {'TP': 4, 'FP': 0, 'TN': 19109, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1152 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2300, 'FP': 185, 'TN': 16635, 'FN': 24}, 'NOUN': {'TP': 4786, 'FP': 1152, 'TN': 13057, 'FN': 149}, 'ADJ': {'TP': 963, 'FP': 89, 'TN': 17494, 'FN': 598}, 'VERB': {'TP': 2198, 'FP': 101, 'TN': 16308, 'FN': 537}, 'ADP': {'TP': 2354, 'FP': 479, 'TN': 16285, 'FN': 26}, '.': {'TP': 2333, 'FP': 13, 'TN': 16798, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18281, 'FN': 251}, 'CONJ': {'TP': 564, 'FP': 2, 'TN': 18562, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18639, 'FN': 275}, 'PRON': {'TP': 510, 'FP': 2, 'TN': 18599, 'FN': 33}, 'NUM': {'TP': 267, 'FP': 0, 'TN': 18769, 'FN': 108}, 'X': {'TP': 4, 'FP': 0, 'TN': 19109, 'FN': 31}}
# sentence:       ['But', ',', 'he', 'told', 'the', '``', 'skyjackers', "''", ',', 'the', '707', "didn't", 'carry', 'enough', 'fuel', 'to', 'reach', 'Havana', ';', ';', 'they', 'would', 'have', 'to', 'refuel', 'at', 'El', 'Paso', '.']
# hidden s:       ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NUM', 'VERB', 'VERB', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'ADJ', 'NOUN', 'ADP', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2302, 'FP': 185, 'TN': 16662, 'FN': 24}
# NOUN: {'TP': 4791, 'FP': 1154, 'TN': 13079, 'FN': 149}
# ADJ: {'TP': 964, 'FP': 89, 'TN': 17522, 'FN': 598}
# VERB: {'TP': 2204, 'FP': 101, 'TN': 16330, 'FN': 538}
# ADP: {'TP': 2355, 'FP': 481, 'TN': 16311, 'FN': 26}
# .: {'TP': 2340, 'FP': 13, 'TN': 16820, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18310, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18590, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18666, 'FN': 277}
# PRON: {'TP': 512, 'FP': 2, 'TN': 18626, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18797, 'FN': 109}
# X: {'TP': 4, 'FP': 0, 'TN': 19138, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1154 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2302, 'FP': 185, 'TN': 16662, 'FN': 24}, 'NOUN': {'TP': 4791, 'FP': 1154, 'TN': 13079, 'FN': 149}, 'ADJ': {'TP': 964, 'FP': 89, 'TN': 17522, 'FN': 598}, 'VERB': {'TP': 2204, 'FP': 101, 'TN': 16330, 'FN': 538}, 'ADP': {'TP': 2355, 'FP': 481, 'TN': 16311, 'FN': 26}, '.': {'TP': 2340, 'FP': 13, 'TN': 16820, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18310, 'FN': 251}, 'CONJ': {'TP': 565, 'FP': 2, 'TN': 18590, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18666, 'FN': 277}, 'PRON': {'TP': 512, 'FP': 2, 'TN': 18626, 'FN': 33}, 'NUM': {'TP': 267, 'FP': 0, 'TN': 18797, 'FN': 109}, 'X': {'TP': 4, 'FP': 0, 'TN': 19138, 'FN': 31}}
# sentence:       ['Most', 'passengers', "didn't", 'know', 'what', 'had', 'happened', 'until', 'they', 'got', 'on', 'the', 'ground', '.']
# hidden s:       ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2304, 'FP': 185, 'TN': 16674, 'FN': 24}
# NOUN: {'TP': 4793, 'FP': 1154, 'TN': 13091, 'FN': 149}
# ADJ: {'TP': 965, 'FP': 89, 'TN': 17535, 'FN': 598}
# VERB: {'TP': 2209, 'FP': 101, 'TN': 16339, 'FN': 538}
# ADP: {'TP': 2357, 'FP': 481, 'TN': 16323, 'FN': 26}
# .: {'TP': 2341, 'FP': 13, 'TN': 16833, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18324, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18604, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18680, 'FN': 277}
# PRON: {'TP': 513, 'FP': 2, 'TN': 18639, 'FN': 33}
# NUM: {'TP': 267, 'FP': 0, 'TN': 18811, 'FN': 109}
# X: {'TP': 4, 'FP': 0, 'TN': 19152, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1154 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2304, 'FP': 185, 'TN': 16674, 'FN': 24}, 'NOUN': {'TP': 4793, 'FP': 1154, 'TN': 13091, 'FN': 149}, 'ADJ': {'TP': 965, 'FP': 89, 'TN': 17535, 'FN': 598}, 'VERB': {'TP': 2209, 'FP': 101, 'TN': 16339, 'FN': 538}, 'ADP': {'TP': 2357, 'FP': 481, 'TN': 16323, 'FN': 26}, '.': {'TP': 2341, 'FP': 13, 'TN': 16833, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18324, 'FN': 251}, 'CONJ': {'TP': 565, 'FP': 2, 'TN': 18604, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18680, 'FN': 277}, 'PRON': {'TP': 513, 'FP': 2, 'TN': 18639, 'FN': 33}, 'NUM': {'TP': 267, 'FP': 0, 'TN': 18811, 'FN': 109}, 'X': {'TP': 4, 'FP': 0, 'TN': 19152, 'FN': 31}}
# sentence:       ['Jerry', 'McCauley', 'of', 'Sacramento', ',', 'Calif.', ',', 'one', 'of', 'some', 'twenty', 'Air', 'Force', 'recruits', 'on', 'board', ',', 'awoke', 'from', 'a', 'nap', 'in', 'confusion', '.']
# hidden s:       ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2306, 'FP': 185, 'TN': 16696, 'FN': 24}
# NOUN: {'TP': 4803, 'FP': 1156, 'TN': 13103, 'FN': 149}
# ADJ: {'TP': 965, 'FP': 89, 'TN': 17559, 'FN': 598}
# VERB: {'TP': 2209, 'FP': 101, 'TN': 16362, 'FN': 539}
# ADP: {'TP': 2362, 'FP': 481, 'TN': 16342, 'FN': 26}
# .: {'TP': 2345, 'FP': 13, 'TN': 16853, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18348, 'FN': 251}
# CONJ: {'TP': 565, 'FP': 2, 'TN': 18628, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18704, 'FN': 277}
# PRON: {'TP': 513, 'FP': 2, 'TN': 18663, 'FN': 33}
# NUM: {'TP': 268, 'FP': 0, 'TN': 18833, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19176, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1156 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2306, 'FP': 185, 'TN': 16696, 'FN': 24}, 'NOUN': {'TP': 4803, 'FP': 1156, 'TN': 13103, 'FN': 149}, 'ADJ': {'TP': 965, 'FP': 89, 'TN': 17559, 'FN': 598}, 'VERB': {'TP': 2209, 'FP': 101, 'TN': 16362, 'FN': 539}, 'ADP': {'TP': 2362, 'FP': 481, 'TN': 16342, 'FN': 26}, '.': {'TP': 2345, 'FP': 13, 'TN': 16853, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18348, 'FN': 251}, 'CONJ': {'TP': 565, 'FP': 2, 'TN': 18628, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18704, 'FN': 277}, 'PRON': {'TP': 513, 'FP': 2, 'TN': 18663, 'FN': 33}, 'NUM': {'TP': 268, 'FP': 0, 'TN': 18833, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19176, 'FN': 31}}
# sentence:       ['``', 'The', 'old', 'man', 'came', 'from', 'the', 'front', 'of', 'the', 'plane', 'and', 'said', 'he', 'wanted', 'four', 'volunteers', 'to', 'go', 'to', 'Cuba', "''", ',', 'McCauley', 'said', ',', '``', 'and', 'like', 'a', 'nut', 'I', 'raised', 'my', 'hand', '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2311, 'FP': 185, 'TN': 16727, 'FN': 24}
# NOUN: {'TP': 4811, 'FP': 1157, 'TN': 13130, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17594, 'FN': 598}
# VERB: {'TP': 2214, 'FP': 102, 'TN': 16391, 'FN': 540}
# ADP: {'TP': 2365, 'FP': 482, 'TN': 16373, 'FN': 27}
# .: {'TP': 2351, 'FP': 13, 'TN': 16883, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18384, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18662, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18739, 'FN': 278}
# PRON: {'TP': 515, 'FP': 2, 'TN': 18697, 'FN': 33}
# NUM: {'TP': 269, 'FP': 0, 'TN': 18868, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19212, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1157 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2311, 'FP': 185, 'TN': 16727, 'FN': 24}, 'NOUN': {'TP': 4811, 'FP': 1157, 'TN': 13130, 'FN': 149}, 'ADJ': {'TP': 966, 'FP': 89, 'TN': 17594, 'FN': 598}, 'VERB': {'TP': 2214, 'FP': 102, 'TN': 16391, 'FN': 540}, 'ADP': {'TP': 2365, 'FP': 482, 'TN': 16373, 'FN': 27}, '.': {'TP': 2351, 'FP': 13, 'TN': 16883, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18384, 'FN': 251}, 'CONJ': {'TP': 567, 'FP': 2, 'TN': 18662, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18739, 'FN': 278}, 'PRON': {'TP': 515, 'FP': 2, 'TN': 18697, 'FN': 33}, 'NUM': {'TP': 269, 'FP': 0, 'TN': 18868, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19212, 'FN': 31}}
# sentence:       ['I', 'thought', 'he', 'was', 'the', 'Air', 'Force', 'recruiter', "''", '.']
# hidden s:       ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# predictions:    ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# DET: {'TP': 2312, 'FP': 185, 'TN': 16736, 'FN': 24}
# NOUN: {'TP': 4814, 'FP': 1157, 'TN': 13137, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17604, 'FN': 598}
# VERB: {'TP': 2216, 'FP': 102, 'TN': 16399, 'FN': 540}
# ADP: {'TP': 2365, 'FP': 482, 'TN': 16383, 'FN': 27}
# .: {'TP': 2353, 'FP': 13, 'TN': 16891, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18394, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18672, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18749, 'FN': 278}
# PRON: {'TP': 517, 'FP': 2, 'TN': 18705, 'FN': 33}
# NUM: {'TP': 269, 'FP': 0, 'TN': 18878, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19222, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1157 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2312, 'FP': 185, 'TN': 16736, 'FN': 24}, 'NOUN': {'TP': 4814, 'FP': 1157, 'TN': 13137, 'FN': 149}, 'ADJ': {'TP': 966, 'FP': 89, 'TN': 17604, 'FN': 598}, 'VERB': {'TP': 2216, 'FP': 102, 'TN': 16399, 'FN': 540}, 'ADP': {'TP': 2365, 'FP': 482, 'TN': 16383, 'FN': 27}, '.': {'TP': 2353, 'FP': 13, 'TN': 16891, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18394, 'FN': 251}, 'CONJ': {'TP': 567, 'FP': 2, 'TN': 18672, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18749, 'FN': 278}, 'PRON': {'TP': 517, 'FP': 2, 'TN': 18705, 'FN': 33}, 'NUM': {'TP': 269, 'FP': 0, 'TN': 18878, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19222, 'FN': 31}}
# sentence:       ['What', 'the', 'man', 'wanted', 'was', 'four', 'persons', 'to', 'volunteer', 'as', 'hostages', ',', 'along', 'with', 'the', 'crew', '.']
# hidden s:       ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2315, 'FP': 185, 'TN': 16750, 'FN': 24}
# NOUN: {'TP': 4818, 'FP': 1158, 'TN': 13149, 'FN': 149}
# ADJ: {'TP': 966, 'FP': 89, 'TN': 17621, 'FN': 598}
# VERB: {'TP': 2218, 'FP': 102, 'TN': 16413, 'FN': 541}
# ADP: {'TP': 2368, 'FP': 483, 'TN': 16396, 'FN': 27}
# .: {'TP': 2355, 'FP': 13, 'TN': 16906, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18411, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18689, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18765, 'FN': 279}
# PRON: {'TP': 517, 'FP': 2, 'TN': 18722, 'FN': 33}
# NUM: {'TP': 270, 'FP': 0, 'TN': 18894, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19239, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2315, 'FP': 185, 'TN': 16750, 'FN': 24}, 'NOUN': {'TP': 4818, 'FP': 1158, 'TN': 13149, 'FN': 149}, 'ADJ': {'TP': 966, 'FP': 89, 'TN': 17621, 'FN': 598}, 'VERB': {'TP': 2218, 'FP': 102, 'TN': 16413, 'FN': 541}, 'ADP': {'TP': 2368, 'FP': 483, 'TN': 16396, 'FN': 27}, '.': {'TP': 2355, 'FP': 13, 'TN': 16906, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18411, 'FN': 251}, 'CONJ': {'TP': 567, 'FP': 2, 'TN': 18689, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18765, 'FN': 279}, 'PRON': {'TP': 517, 'FP': 2, 'TN': 18722, 'FN': 33}, 'NUM': {'TP': 270, 'FP': 0, 'TN': 18894, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19239, 'FN': 31}}
# sentence:       ['They', 'chose', 'four', ':', 'Jack', 'Casey', ',', 'who', 'works', 'for', 'Continental', 'Airlines', 'in', 'Houston', ';', ';', 'Fred', 'Mullen', 'from', 'Mercer', 'Island', ',', 'Wash.', ';', ';', 'Pfc.', 'Truman', 'Cleveland', 'of', 'St.', 'Augustine', '.']
# hidden s:       ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2315, 'FP': 185, 'TN': 16782, 'FN': 24}
# NOUN: {'TP': 4832, 'FP': 1158, 'TN': 13167, 'FN': 149}
# ADJ: {'TP': 967, 'FP': 89, 'TN': 17652, 'FN': 598}
# VERB: {'TP': 2220, 'FP': 102, 'TN': 16443, 'FN': 541}
# ADP: {'TP': 2372, 'FP': 483, 'TN': 16424, 'FN': 27}
# .: {'TP': 2363, 'FP': 13, 'TN': 16930, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18443, 'FN': 251}
# CONJ: {'TP': 567, 'FP': 2, 'TN': 18721, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18797, 'FN': 279}
# PRON: {'TP': 519, 'FP': 2, 'TN': 18752, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18925, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19271, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2315, 'FP': 185, 'TN': 16782, 'FN': 24}, 'NOUN': {'TP': 4832, 'FP': 1158, 'TN': 13167, 'FN': 149}, 'ADJ': {'TP': 967, 'FP': 89, 'TN': 17652, 'FN': 598}, 'VERB': {'TP': 2220, 'FP': 102, 'TN': 16443, 'FN': 541}, 'ADP': {'TP': 2372, 'FP': 483, 'TN': 16424, 'FN': 27}, '.': {'TP': 2363, 'FP': 13, 'TN': 16930, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18443, 'FN': 251}, 'CONJ': {'TP': 567, 'FP': 2, 'TN': 18721, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18797, 'FN': 279}, 'PRON': {'TP': 519, 'FP': 2, 'TN': 18752, 'FN': 33}, 'NUM': {'TP': 271, 'FP': 0, 'TN': 18925, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19271, 'FN': 31}}
# sentence:       ['Fla.', ',', 'and', 'Leonard', 'Gilman', ',', 'a', 'former', 'college', 'boxer', 'and', 'veteran', 'of', 'the', 'U.S.', 'Immigration', 'Service', 'Border', 'Patrol', '.']
# hidden s:       ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2317, 'FP': 185, 'TN': 16800, 'FN': 24}
# NOUN: {'TP': 4843, 'FP': 1158, 'TN': 13176, 'FN': 149}
# ADJ: {'TP': 968, 'FP': 89, 'TN': 17671, 'FN': 598}
# VERB: {'TP': 2220, 'FP': 102, 'TN': 16463, 'FN': 541}
# ADP: {'TP': 2373, 'FP': 483, 'TN': 16443, 'FN': 27}
# .: {'TP': 2366, 'FP': 13, 'TN': 16947, 'FN': 0}
# ADV: {'TP': 595, 'FP': 17, 'TN': 18463, 'FN': 251}
# CONJ: {'TP': 569, 'FP': 2, 'TN': 18739, 'FN': 16}
# PRT: {'TP': 222, 'FP': 8, 'TN': 18817, 'FN': 279}
# PRON: {'TP': 519, 'FP': 2, 'TN': 18772, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18945, 'FN': 110}
# X: {'TP': 4, 'FP': 0, 'TN': 19291, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1158 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2317, 'FP': 185, 'TN': 16800, 'FN': 24}, 'NOUN': {'TP': 4843, 'FP': 1158, 'TN': 13176, 'FN': 149}, 'ADJ': {'TP': 968, 'FP': 89, 'TN': 17671, 'FN': 598}, 'VERB': {'TP': 2220, 'FP': 102, 'TN': 16463, 'FN': 541}, 'ADP': {'TP': 2373, 'FP': 483, 'TN': 16443, 'FN': 27}, '.': {'TP': 2366, 'FP': 13, 'TN': 16947, 'FN': 0}, 'ADV': {'TP': 595, 'FP': 17, 'TN': 18463, 'FN': 251}, 'CONJ': {'TP': 569, 'FP': 2, 'TN': 18739, 'FN': 16}, 'PRT': {'TP': 222, 'FP': 8, 'TN': 18817, 'FN': 279}, 'PRON': {'TP': 519, 'FP': 2, 'TN': 18772, 'FN': 33}, 'NUM': {'TP': 271, 'FP': 0, 'TN': 18945, 'FN': 110}, 'X': {'TP': 4, 'FP': 0, 'TN': 19291, 'FN': 31}}
# sentence:       ['Everybody', 'else', 'was', 'allowed', 'to', 'file', 'off', 'the', 'plane', 'after', 'it', 'touched', 'down', 'at', 'El', 'Paso', 'at', '4:18', 'a.m.', '.']
# hidden s:       ['NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NUM', 'ADV', '.']
# predictions:    ['NOUN', 'ADV', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADV', '.']
# DET: {'TP': 2318, 'FP': 185, 'TN': 16819, 'FN': 24}
# NOUN: {'TP': 4847, 'FP': 1160, 'TN': 13190, 'FN': 149}
# ADJ: {'TP': 968, 'FP': 89, 'TN': 17691, 'FN': 598}
# VERB: {'TP': 2223, 'FP': 102, 'TN': 16479, 'FN': 542}
# ADP: {'TP': 2377, 'FP': 484, 'TN': 16458, 'FN': 27}
# .: {'TP': 2367, 'FP': 13, 'TN': 16966, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18481, 'FN': 251}
# CONJ: {'TP': 569, 'FP': 2, 'TN': 18759, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18835, 'FN': 280}
# PRON: {'TP': 520, 'FP': 2, 'TN': 18791, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18964, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19311, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1160 counts.
# Tag with the most false negative is:  ADJ with 598 counts.
# confusion_matrices: {'DET': {'TP': 2318, 'FP': 185, 'TN': 16819, 'FN': 24}, 'NOUN': {'TP': 4847, 'FP': 1160, 'TN': 13190, 'FN': 149}, 'ADJ': {'TP': 968, 'FP': 89, 'TN': 17691, 'FN': 598}, 'VERB': {'TP': 2223, 'FP': 102, 'TN': 16479, 'FN': 542}, 'ADP': {'TP': 2377, 'FP': 484, 'TN': 16458, 'FN': 27}, '.': {'TP': 2367, 'FP': 13, 'TN': 16966, 'FN': 0}, 'ADV': {'TP': 597, 'FP': 17, 'TN': 18481, 'FN': 251}, 'CONJ': {'TP': 569, 'FP': 2, 'TN': 18759, 'FN': 16}, 'PRT': {'TP': 223, 'FP': 8, 'TN': 18835, 'FN': 280}, 'PRON': {'TP': 520, 'FP': 2, 'TN': 18791, 'FN': 33}, 'NUM': {'TP': 271, 'FP': 0, 'TN': 18964, 'FN': 111}, 'X': {'TP': 4, 'FP': 0, 'TN': 19311, 'FN': 31}}
# sentence:       ['They', 'found', 'a', 'large', 'welcoming', 'group', '--', 'El', 'Paso', 'policemen', ',', 'Border', 'Patrol', ',', "sheriff's", 'deputies', ',', 'and', 'FBI', 'men', ',', 'who', 'surged', 'around', 'the', 'plane', 'with', 'rifles', 'and', 'submachine', 'guns', '.']
# hidden s:       ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2320, 'FP': 185, 'TN': 16849, 'FN': 24}
# NOUN: {'TP': 4860, 'FP': 1161, 'TN': 13208, 'FN': 149}
# ADJ: {'TP': 969, 'FP': 89, 'TN': 17721, 'FN': 599}
# VERB: {'TP': 2226, 'FP': 102, 'TN': 16508, 'FN': 542}
# ADP: {'TP': 2379, 'FP': 484, 'TN': 16488, 'FN': 27}
# .: {'TP': 2373, 'FP': 13, 'TN': 16992, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18513, 'FN': 251}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18789, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18867, 'FN': 280}
# PRON: {'TP': 522, 'FP': 2, 'TN': 18821, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 18996, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19343, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1161 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# confusion_matrices: {'DET': {'TP': 2320, 'FP': 185, 'TN': 16849, 'FN': 24}, 'NOUN': {'TP': 4860, 'FP': 1161, 'TN': 13208, 'FN': 149}, 'ADJ': {'TP': 969, 'FP': 89, 'TN': 17721, 'FN': 599}, 'VERB': {'TP': 2226, 'FP': 102, 'TN': 16508, 'FN': 542}, 'ADP': {'TP': 2379, 'FP': 484, 'TN': 16488, 'FN': 27}, '.': {'TP': 2373, 'FP': 13, 'TN': 16992, 'FN': 0}, 'ADV': {'TP': 597, 'FP': 17, 'TN': 18513, 'FN': 251}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18789, 'FN': 16}, 'PRT': {'TP': 223, 'FP': 8, 'TN': 18867, 'FN': 280}, 'PRON': {'TP': 522, 'FP': 2, 'TN': 18821, 'FN': 33}, 'NUM': {'TP': 271, 'FP': 0, 'TN': 18996, 'FN': 111}, 'X': {'TP': 4, 'FP': 0, 'TN': 19343, 'FN': 31}}
# sentence:       ['Other', 'FBI', 'men', ',', 'talking', 'with', 'the', 'pilot', 'from', 'the', 'tower', ',', 'conspired', 'with', 'him', 'to', 'delay', 'the', 'proposed', 'flight', 'to', 'Havana', '.']
# hidden s:       ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'PRON', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'ADP', 'PRON', 'ADP', 'NOUN', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2323, 'FP': 185, 'TN': 16869, 'FN': 24}
# NOUN: {'TP': 4866, 'FP': 1163, 'TN': 13223, 'FN': 149}
# ADJ: {'TP': 970, 'FP': 89, 'TN': 17743, 'FN': 599}
# VERB: {'TP': 2228, 'FP': 102, 'TN': 16527, 'FN': 544}
# ADP: {'TP': 2383, 'FP': 485, 'TN': 16506, 'FN': 27}
# .: {'TP': 2376, 'FP': 13, 'TN': 17012, 'FN': 0}
# ADV: {'TP': 597, 'FP': 17, 'TN': 18536, 'FN': 251}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18812, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18889, 'FN': 281}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18843, 'FN': 33}
# NUM: {'TP': 271, 'FP': 0, 'TN': 19019, 'FN': 111}
# X: {'TP': 4, 'FP': 0, 'TN': 19366, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1163 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# confusion_matrices: {'DET': {'TP': 2323, 'FP': 185, 'TN': 16869, 'FN': 24}, 'NOUN': {'TP': 4866, 'FP': 1163, 'TN': 13223, 'FN': 149}, 'ADJ': {'TP': 970, 'FP': 89, 'TN': 17743, 'FN': 599}, 'VERB': {'TP': 2228, 'FP': 102, 'TN': 16527, 'FN': 544}, 'ADP': {'TP': 2383, 'FP': 485, 'TN': 16506, 'FN': 27}, '.': {'TP': 2376, 'FP': 13, 'TN': 17012, 'FN': 0}, 'ADV': {'TP': 597, 'FP': 17, 'TN': 18536, 'FN': 251}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18812, 'FN': 16}, 'PRT': {'TP': 223, 'FP': 8, 'TN': 18889, 'FN': 281}, 'PRON': {'TP': 523, 'FP': 2, 'TN': 18843, 'FN': 33}, 'NUM': {'TP': 271, 'FP': 0, 'TN': 19019, 'FN': 111}, 'X': {'TP': 4, 'FP': 0, 'TN': 19366, 'FN': 31}}
# sentence:       ['The', 'ground', 'crew', ',', 'which', 'ordinarily', 'fuels', 'a', '707', 'in', 'twenty', 'minutes', ',', 'took', 'fully', 'three', 'hours', '.']
# hidden s:       ['DET', 'NOUN', 'NOUN', '.', 'DET', 'ADV', 'VERB', 'DET', 'NUM', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# DET: {'TP': 2326, 'FP': 185, 'TN': 16884, 'FN': 24}
# NOUN: {'TP': 4870, 'FP': 1165, 'TN': 13235, 'FN': 149}
# ADJ: {'TP': 970, 'FP': 89, 'TN': 17761, 'FN': 599}
# VERB: {'TP': 2229, 'FP': 102, 'TN': 16543, 'FN': 545}
# ADP: {'TP': 2384, 'FP': 486, 'TN': 16522, 'FN': 27}
# .: {'TP': 2379, 'FP': 13, 'TN': 17027, 'FN': 0}
# ADV: {'TP': 598, 'FP': 17, 'TN': 18552, 'FN': 252}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18830, 'FN': 16}
# PRT: {'TP': 223, 'FP': 8, 'TN': 18907, 'FN': 281}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18861, 'FN': 33}
# NUM: {'TP': 273, 'FP': 0, 'TN': 19034, 'FN': 112}
# X: {'TP': 4, 'FP': 0, 'TN': 19384, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1165 counts.
# Tag with the most false negative is:  ADJ with 599 counts.
# confusion_matrices: {'DET': {'TP': 2326, 'FP': 185, 'TN': 16884, 'FN': 24}, 'NOUN': {'TP': 4870, 'FP': 1165, 'TN': 13235, 'FN': 149}, 'ADJ': {'TP': 970, 'FP': 89, 'TN': 17761, 'FN': 599}, 'VERB': {'TP': 2229, 'FP': 102, 'TN': 16543, 'FN': 545}, 'ADP': {'TP': 2384, 'FP': 486, 'TN': 16522, 'FN': 27}, '.': {'TP': 2379, 'FP': 13, 'TN': 17027, 'FN': 0}, 'ADV': {'TP': 598, 'FP': 17, 'TN': 18552, 'FN': 252}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18830, 'FN': 16}, 'PRT': {'TP': 223, 'FP': 8, 'TN': 18907, 'FN': 281}, 'PRON': {'TP': 523, 'FP': 2, 'TN': 18861, 'FN': 33}, 'NUM': {'TP': 273, 'FP': 0, 'TN': 19034, 'FN': 112}, 'X': {'TP': 4, 'FP': 0, 'TN': 19384, 'FN': 31}}
# sentence:       ['Still', 'more', 'time', 'was', 'consumed', 'while', 'the', 'pilot', ',', 'at', 'the', 'radioed', 'suggestion', 'of', 'Continental', 'president', 'Robert', 'Six', ',', 'tried', 'to', 'persuade', 'the', 'armed', 'pair', 'to', 'swap', 'the', 'Boeing', 'jet', 'for', 'a', 'propeller-driven', 'Douglas', 'Aj', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NUM', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2331, 'FP': 185, 'TN': 16915, 'FN': 24}
# NOUN: {'TP': 4880, 'FP': 1169, 'TN': 13256, 'FN': 150}
# ADJ: {'TP': 972, 'FP': 89, 'TN': 17794, 'FN': 600}
# VERB: {'TP': 2233, 'FP': 102, 'TN': 16572, 'FN': 548}
# ADP: {'TP': 2388, 'FP': 487, 'TN': 16553, 'FN': 27}
# .: {'TP': 2382, 'FP': 13, 'TN': 17060, 'FN': 0}
# ADV: {'TP': 599, 'FP': 17, 'TN': 18587, 'FN': 252}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18866, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 18941, 'FN': 282}
# PRON: {'TP': 523, 'FP': 2, 'TN': 18897, 'FN': 33}
# NUM: {'TP': 273, 'FP': 1, 'TN': 19069, 'FN': 112}
# X: {'TP': 4, 'FP': 0, 'TN': 19420, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1169 counts.
# Tag with the most false negative is:  ADJ with 600 counts.
# confusion_matrices: {'DET': {'TP': 2331, 'FP': 185, 'TN': 16915, 'FN': 24}, 'NOUN': {'TP': 4880, 'FP': 1169, 'TN': 13256, 'FN': 150}, 'ADJ': {'TP': 972, 'FP': 89, 'TN': 17794, 'FN': 600}, 'VERB': {'TP': 2233, 'FP': 102, 'TN': 16572, 'FN': 548}, 'ADP': {'TP': 2388, 'FP': 487, 'TN': 16553, 'FN': 27}, '.': {'TP': 2382, 'FP': 13, 'TN': 17060, 'FN': 0}, 'ADV': {'TP': 599, 'FP': 17, 'TN': 18587, 'FN': 252}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18866, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 18941, 'FN': 282}, 'PRON': {'TP': 523, 'FP': 2, 'TN': 18897, 'FN': 33}, 'NUM': {'TP': 273, 'FP': 1, 'TN': 19069, 'FN': 112}, 'X': {'TP': 4, 'FP': 0, 'TN': 19420, 'FN': 31}}
# sentence:       ['Actually', ',', 'the', 'officers', 'on', 'the', 'ground', 'had', 'no', 'intention', 'of', 'letting', 'the', 'hijackers', 'get', 'away', 'with', 'any', 'kind', 'of', 'an', 'airplane', ';', ';', 'they', 'had', 'orders', 'to', 'that', 'effect', 'straight', 'from', 'President', 'Kennedy', ',', 'who', 'thought', 'at', 'first', ',', 'as', 'did', 'most', 'others', ',', 'that', 'it', 'was', 'four', 'followers', 'of', "Cuba's", 'Fidel', 'Castro', 'who', 'had', 'taken', 'over', 'the', '707', '.']
# hidden s:       ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'DET', 'NUM', '.']
# predictions:    ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADP', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2339, 'FP': 186, 'TN': 16967, 'FN': 24}
# NOUN: {'TP': 4893, 'FP': 1171, 'TN': 13301, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17851, 'FN': 601}
# VERB: {'TP': 2242, 'FP': 102, 'TN': 16624, 'FN': 548}
# ADP: {'TP': 2397, 'FP': 489, 'TN': 16603, 'FN': 27}
# .: {'TP': 2389, 'FP': 13, 'TN': 17114, 'FN': 0}
# ADV: {'TP': 601, 'FP': 17, 'TN': 18644, 'FN': 254}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18927, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19001, 'FN': 283}
# PRON: {'TP': 527, 'FP': 2, 'TN': 18954, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19128, 'FN': 113}
# X: {'TP': 4, 'FP': 0, 'TN': 19481, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1171 counts.
# Tag with the most false negative is:  ADJ with 601 counts.
# confusion_matrices: {'DET': {'TP': 2339, 'FP': 186, 'TN': 16967, 'FN': 24}, 'NOUN': {'TP': 4893, 'FP': 1171, 'TN': 13301, 'FN': 151}, 'ADJ': {'TP': 974, 'FP': 90, 'TN': 17851, 'FN': 601}, 'VERB': {'TP': 2242, 'FP': 102, 'TN': 16624, 'FN': 548}, 'ADP': {'TP': 2397, 'FP': 489, 'TN': 16603, 'FN': 27}, '.': {'TP': 2389, 'FP': 13, 'TN': 17114, 'FN': 0}, 'ADV': {'TP': 601, 'FP': 17, 'TN': 18644, 'FN': 254}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18927, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 19001, 'FN': 283}, 'PRON': {'TP': 527, 'FP': 2, 'TN': 18954, 'FN': 33}, 'NUM': {'TP': 274, 'FP': 1, 'TN': 19128, 'FN': 113}, 'X': {'TP': 4, 'FP': 0, 'TN': 19481, 'FN': 31}}
# sentence:       ['Mr.', 'Kennedy', 'had', 'been', 'informed', 'early', 'in', 'the', 'day', 'of', 'the', 'attempt', 'to', 'steal', 'the', 'plane', ',', 'kept', 'in', 'touch', 'throughout', 'by', 'telephone', '.']
# hidden s:       ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADP', 'NOUN', '.']
# DET: {'TP': 2342, 'FP': 186, 'TN': 16988, 'FN': 24}
# NOUN: {'TP': 4900, 'FP': 1172, 'TN': 13317, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17875, 'FN': 601}
# VERB: {'TP': 2246, 'FP': 102, 'TN': 16643, 'FN': 549}
# ADP: {'TP': 2401, 'FP': 491, 'TN': 16621, 'FN': 27}
# .: {'TP': 2391, 'FP': 13, 'TN': 17136, 'FN': 0}
# ADV: {'TP': 602, 'FP': 17, 'TN': 18666, 'FN': 255}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18951, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19024, 'FN': 284}
# PRON: {'TP': 527, 'FP': 2, 'TN': 18978, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19152, 'FN': 113}
# X: {'TP': 4, 'FP': 0, 'TN': 19505, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1172 counts.
# Tag with the most false negative is:  ADJ with 601 counts.
# confusion_matrices: {'DET': {'TP': 2342, 'FP': 186, 'TN': 16988, 'FN': 24}, 'NOUN': {'TP': 4900, 'FP': 1172, 'TN': 13317, 'FN': 151}, 'ADJ': {'TP': 974, 'FP': 90, 'TN': 17875, 'FN': 601}, 'VERB': {'TP': 2246, 'FP': 102, 'TN': 16643, 'FN': 549}, 'ADP': {'TP': 2401, 'FP': 491, 'TN': 16621, 'FN': 27}, '.': {'TP': 2391, 'FP': 13, 'TN': 17136, 'FN': 0}, 'ADV': {'TP': 602, 'FP': 17, 'TN': 18666, 'FN': 255}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18951, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 19024, 'FN': 284}, 'PRON': {'TP': 527, 'FP': 2, 'TN': 18978, 'FN': 33}, 'NUM': {'TP': 274, 'FP': 1, 'TN': 19152, 'FN': 113}, 'X': {'TP': 4, 'FP': 0, 'TN': 19505, 'FN': 31}}
# sentence:       ['At', 'one', 'time', ',', 'while', 'still', 'under', 'the', 'impression', 'that', 'he', 'was', 'dealing', 'with', 'a', 'Cuban', 'plot', ',', 'the', 'President', 'talked', 'about', 'invoking', 'a', 'total', 'embargo', 'on', 'trade', 'with', 'Cuba', '.']
# hidden s:       ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2346, 'FP': 186, 'TN': 17015, 'FN': 24}
# NOUN: {'TP': 4908, 'FP': 1175, 'TN': 13337, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 90, 'TN': 17905, 'FN': 602}
# VERB: {'TP': 2250, 'FP': 102, 'TN': 16670, 'FN': 549}
# ADP: {'TP': 2408, 'FP': 491, 'TN': 16644, 'FN': 28}
# .: {'TP': 2394, 'FP': 13, 'TN': 17164, 'FN': 0}
# ADV: {'TP': 603, 'FP': 17, 'TN': 18696, 'FN': 255}
# CONJ: {'TP': 571, 'FP': 2, 'TN': 18982, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19055, 'FN': 284}
# PRON: {'TP': 528, 'FP': 2, 'TN': 19008, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19182, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19536, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1175 counts.
# Tag with the most false negative is:  ADJ with 602 counts.
# confusion_matrices: {'DET': {'TP': 2346, 'FP': 186, 'TN': 17015, 'FN': 24}, 'NOUN': {'TP': 4908, 'FP': 1175, 'TN': 13337, 'FN': 151}, 'ADJ': {'TP': 974, 'FP': 90, 'TN': 17905, 'FN': 602}, 'VERB': {'TP': 2250, 'FP': 102, 'TN': 16670, 'FN': 549}, 'ADP': {'TP': 2408, 'FP': 491, 'TN': 16644, 'FN': 28}, '.': {'TP': 2394, 'FP': 13, 'TN': 17164, 'FN': 0}, 'ADV': {'TP': 603, 'FP': 17, 'TN': 18696, 'FN': 255}, 'CONJ': {'TP': 571, 'FP': 2, 'TN': 18982, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 19055, 'FN': 284}, 'PRON': {'TP': 528, 'FP': 2, 'TN': 19008, 'FN': 33}, 'NUM': {'TP': 274, 'FP': 1, 'TN': 19182, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19536, 'FN': 31}}
# sentence:       ['As', 'the', 'morning', 'wore', 'on', 'and', 'a', 'blazing', 'West', 'Texas', 'sun', 'wiped', 'the', 'shadows', 'off', 'the', 'Franklin', 'Mountains', ',', 'police', 'got', 'close', 'enough', 'to', 'the', 'plane', 'to', 'pry', 'into', 'the', 'baggage', 'compartment', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'CONJ', 'DET', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2352, 'FP': 186, 'TN': 17042, 'FN': 24}
# NOUN: {'TP': 4918, 'FP': 1177, 'TN': 13358, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 17936, 'FN': 603}
# VERB: {'TP': 2254, 'FP': 103, 'TN': 16697, 'FN': 550}
# ADP: {'TP': 2412, 'FP': 493, 'TN': 16671, 'FN': 28}
# .: {'TP': 2396, 'FP': 13, 'TN': 17195, 'FN': 0}
# ADV: {'TP': 603, 'FP': 17, 'TN': 18727, 'FN': 257}
# CONJ: {'TP': 572, 'FP': 2, 'TN': 19014, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19086, 'FN': 286}
# PRON: {'TP': 528, 'FP': 2, 'TN': 19041, 'FN': 33}
# NUM: {'TP': 274, 'FP': 1, 'TN': 19215, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19569, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1177 counts.
# Tag with the most false negative is:  ADJ with 603 counts.
# confusion_matrices: {'DET': {'TP': 2352, 'FP': 186, 'TN': 17042, 'FN': 24}, 'NOUN': {'TP': 4918, 'FP': 1177, 'TN': 13358, 'FN': 151}, 'ADJ': {'TP': 974, 'FP': 91, 'TN': 17936, 'FN': 603}, 'VERB': {'TP': 2254, 'FP': 103, 'TN': 16697, 'FN': 550}, 'ADP': {'TP': 2412, 'FP': 493, 'TN': 16671, 'FN': 28}, '.': {'TP': 2396, 'FP': 13, 'TN': 17195, 'FN': 0}, 'ADV': {'TP': 603, 'FP': 17, 'TN': 18727, 'FN': 257}, 'CONJ': {'TP': 572, 'FP': 2, 'TN': 19014, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 19086, 'FN': 286}, 'PRON': {'TP': 528, 'FP': 2, 'TN': 19041, 'FN': 33}, 'NUM': {'TP': 274, 'FP': 1, 'TN': 19215, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19569, 'FN': 31}}
# sentence:       ['From', 'the', 'luggage', ',', 'they', 'learned', 'that', 'the', 'two', 'air', 'pirates', ',', 'far', 'from', 'being', 'Cubans', ',', 'were', 'native', 'Americans', ',', 'subsequently', 'identified', 'as', 'Leon', 'Bearden', ',', '50-year-old', 'ex-convict', 'from', 'Coolidge', ',', 'Ariz.', ',', 'and', 'his', 'son', ',', 'Cody', ',', '16', ',', 'a', 'high-school', 'junior', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2356, 'FP': 186, 'TN': 17084, 'FN': 24}
# NOUN: {'TP': 4932, 'FP': 1180, 'TN': 13387, 'FN': 151}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 17980, 'FN': 605}
# VERB: {'TP': 2258, 'FP': 103, 'TN': 16739, 'FN': 550}
# ADP: {'TP': 2417, 'FP': 493, 'TN': 16712, 'FN': 28}
# .: {'TP': 2407, 'FP': 13, 'TN': 17230, 'FN': 0}
# ADV: {'TP': 604, 'FP': 17, 'TN': 18771, 'FN': 258}
# CONJ: {'TP': 573, 'FP': 2, 'TN': 19059, 'FN': 16}
# PRT: {'TP': 224, 'FP': 8, 'TN': 19132, 'FN': 286}
# PRON: {'TP': 529, 'FP': 2, 'TN': 19086, 'FN': 33}
# NUM: {'TP': 276, 'FP': 1, 'TN': 19259, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19615, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1180 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# confusion_matrices: {'DET': {'TP': 2356, 'FP': 186, 'TN': 17084, 'FN': 24}, 'NOUN': {'TP': 4932, 'FP': 1180, 'TN': 13387, 'FN': 151}, 'ADJ': {'TP': 974, 'FP': 91, 'TN': 17980, 'FN': 605}, 'VERB': {'TP': 2258, 'FP': 103, 'TN': 16739, 'FN': 550}, 'ADP': {'TP': 2417, 'FP': 493, 'TN': 16712, 'FN': 28}, '.': {'TP': 2407, 'FP': 13, 'TN': 17230, 'FN': 0}, 'ADV': {'TP': 604, 'FP': 17, 'TN': 18771, 'FN': 258}, 'CONJ': {'TP': 573, 'FP': 2, 'TN': 19059, 'FN': 16}, 'PRT': {'TP': 224, 'FP': 8, 'TN': 19132, 'FN': 286}, 'PRON': {'TP': 529, 'FP': 2, 'TN': 19086, 'FN': 33}, 'NUM': {'TP': 276, 'FP': 1, 'TN': 19259, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19615, 'FN': 31}}
# sentence:       ['Tension', 'The', 'heat', 'and', 'strain', 'began', 'to', 'tell', 'on', 'the', 'Beardens', '.']
# hidden s:       ['NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2358, 'FP': 186, 'TN': 17094, 'FN': 24}
# NOUN: {'TP': 4935, 'FP': 1180, 'TN': 13395, 'FN': 152}
# ADJ: {'TP': 974, 'FP': 91, 'TN': 17992, 'FN': 605}
# VERB: {'TP': 2260, 'FP': 103, 'TN': 16749, 'FN': 550}
# ADP: {'TP': 2418, 'FP': 494, 'TN': 16722, 'FN': 28}
# .: {'TP': 2408, 'FP': 13, 'TN': 17241, 'FN': 0}
# ADV: {'TP': 604, 'FP': 17, 'TN': 18783, 'FN': 258}
# CONJ: {'TP': 574, 'FP': 2, 'TN': 19070, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19143, 'FN': 286}
# PRON: {'TP': 529, 'FP': 2, 'TN': 19098, 'FN': 33}
# NUM: {'TP': 276, 'FP': 1, 'TN': 19271, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19627, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1180 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# confusion_matrices: {'DET': {'TP': 2358, 'FP': 186, 'TN': 17094, 'FN': 24}, 'NOUN': {'TP': 4935, 'FP': 1180, 'TN': 13395, 'FN': 152}, 'ADJ': {'TP': 974, 'FP': 91, 'TN': 17992, 'FN': 605}, 'VERB': {'TP': 2260, 'FP': 103, 'TN': 16749, 'FN': 550}, 'ADP': {'TP': 2418, 'FP': 494, 'TN': 16722, 'FN': 28}, '.': {'TP': 2408, 'FP': 13, 'TN': 17241, 'FN': 0}, 'ADV': {'TP': 604, 'FP': 17, 'TN': 18783, 'FN': 258}, 'CONJ': {'TP': 574, 'FP': 2, 'TN': 19070, 'FN': 16}, 'PRT': {'TP': 225, 'FP': 8, 'TN': 19143, 'FN': 286}, 'PRON': {'TP': 529, 'FP': 2, 'TN': 19098, 'FN': 33}, 'NUM': {'TP': 276, 'FP': 1, 'TN': 19271, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19627, 'FN': 31}}
# sentence:       ['The', 'father', ',', 'by', 'accident', 'or', 'perhaps', 'to', 'show', ',', 'as', 'he', 'said', ',', '``', 'we', 'mean', 'business', "''", ',', 'took', 'the', 'and', 'fired', 'a', 'slug', 'between', 'the', 'legs', 'of', 'Second', 'Officer', 'Norman', 'Simmons', '.']
# hidden s:       ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'ADP', 'NOUN', '.', 'ADP', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2362, 'FP': 186, 'TN': 17125, 'FN': 24}
# NOUN: {'TP': 4943, 'FP': 1181, 'TN': 13421, 'FN': 152}
# ADJ: {'TP': 975, 'FP': 91, 'TN': 18026, 'FN': 605}
# VERB: {'TP': 2264, 'FP': 103, 'TN': 16779, 'FN': 551}
# ADP: {'TP': 2422, 'FP': 495, 'TN': 16752, 'FN': 28}
# .: {'TP': 2415, 'FP': 13, 'TN': 17269, 'FN': 0}
# ADV: {'TP': 605, 'FP': 17, 'TN': 18817, 'FN': 258}
# CONJ: {'TP': 576, 'FP': 2, 'TN': 19103, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19177, 'FN': 287}
# PRON: {'TP': 531, 'FP': 2, 'TN': 19131, 'FN': 33}
# NUM: {'TP': 276, 'FP': 1, 'TN': 19306, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19662, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1181 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# confusion_matrices: {'DET': {'TP': 2362, 'FP': 186, 'TN': 17125, 'FN': 24}, 'NOUN': {'TP': 4943, 'FP': 1181, 'TN': 13421, 'FN': 152}, 'ADJ': {'TP': 975, 'FP': 91, 'TN': 18026, 'FN': 605}, 'VERB': {'TP': 2264, 'FP': 103, 'TN': 16779, 'FN': 551}, 'ADP': {'TP': 2422, 'FP': 495, 'TN': 16752, 'FN': 28}, '.': {'TP': 2415, 'FP': 13, 'TN': 17269, 'FN': 0}, 'ADV': {'TP': 605, 'FP': 17, 'TN': 18817, 'FN': 258}, 'CONJ': {'TP': 576, 'FP': 2, 'TN': 19103, 'FN': 16}, 'PRT': {'TP': 225, 'FP': 8, 'TN': 19177, 'FN': 287}, 'PRON': {'TP': 531, 'FP': 2, 'TN': 19131, 'FN': 33}, 'NUM': {'TP': 276, 'FP': 1, 'TN': 19306, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19662, 'FN': 31}}
# sentence:       ['At', '7:30', 'a.m.', ',', 'more', 'than', 'three', 'hours', 'after', 'landing', ',', 'the', 'Beardens', 'gave', 'an', 'ultimatum', ':', 'Take', 'off', 'or', 'see', 'the', 'hostages', 'killed', '.']
# hidden s:       ['ADP', 'NUM', 'ADV', '.', 'ADJ', 'ADP', 'NUM', 'NOUN', 'ADP', 'VERB', '.', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'VERB', '.']
# predictions:    ['ADP', 'NUM', 'ADV', '.', 'ADJ', 'ADP', 'NUM', 'NOUN', 'ADP', 'VERB', '.', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'CONJ', 'VERB', 'DET', 'NOUN', 'VERB', '.']
# DET: {'TP': 2365, 'FP': 186, 'TN': 17147, 'FN': 24}
# NOUN: {'TP': 4947, 'FP': 1181, 'TN': 13442, 'FN': 152}
# ADJ: {'TP': 976, 'FP': 91, 'TN': 18050, 'FN': 605}
# VERB: {'TP': 2269, 'FP': 103, 'TN': 16799, 'FN': 551}
# ADP: {'TP': 2425, 'FP': 496, 'TN': 16773, 'FN': 28}
# .: {'TP': 2419, 'FP': 13, 'TN': 17290, 'FN': 0}
# ADV: {'TP': 606, 'FP': 17, 'TN': 18841, 'FN': 258}
# CONJ: {'TP': 577, 'FP': 2, 'TN': 19127, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19201, 'FN': 288}
# PRON: {'TP': 531, 'FP': 2, 'TN': 19156, 'FN': 33}
# NUM: {'TP': 278, 'FP': 1, 'TN': 19329, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19687, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1181 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# confusion_matrices: {'DET': {'TP': 2365, 'FP': 186, 'TN': 17147, 'FN': 24}, 'NOUN': {'TP': 4947, 'FP': 1181, 'TN': 13442, 'FN': 152}, 'ADJ': {'TP': 976, 'FP': 91, 'TN': 18050, 'FN': 605}, 'VERB': {'TP': 2269, 'FP': 103, 'TN': 16799, 'FN': 551}, 'ADP': {'TP': 2425, 'FP': 496, 'TN': 16773, 'FN': 28}, '.': {'TP': 2419, 'FP': 13, 'TN': 17290, 'FN': 0}, 'ADV': {'TP': 606, 'FP': 17, 'TN': 18841, 'FN': 258}, 'CONJ': {'TP': 577, 'FP': 2, 'TN': 19127, 'FN': 16}, 'PRT': {'TP': 225, 'FP': 8, 'TN': 19201, 'FN': 288}, 'PRON': {'TP': 531, 'FP': 2, 'TN': 19156, 'FN': 33}, 'NUM': {'TP': 278, 'FP': 1, 'TN': 19329, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19687, 'FN': 31}}
# sentence:       ['The', 'tower', 'cleared', 'the', 'plane', 'for', 'take-off', 'at', '8', 'a.m.', ',', 'and', 'Captain', 'Rickards', 'began', 'taxiing', 'toward', 'the', 'runway', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NUM', 'ADV', '.', 'CONJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NUM', 'ADV', '.', 'CONJ', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2368, 'FP': 186, 'TN': 17164, 'FN': 24}
# NOUN: {'TP': 4953, 'FP': 1182, 'TN': 13455, 'FN': 152}
# ADJ: {'TP': 976, 'FP': 91, 'TN': 18070, 'FN': 605}
# VERB: {'TP': 2271, 'FP': 103, 'TN': 16816, 'FN': 552}
# ADP: {'TP': 2428, 'FP': 496, 'TN': 16790, 'FN': 28}
# .: {'TP': 2421, 'FP': 13, 'TN': 17308, 'FN': 0}
# ADV: {'TP': 607, 'FP': 17, 'TN': 18860, 'FN': 258}
# CONJ: {'TP': 578, 'FP': 2, 'TN': 19146, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19221, 'FN': 288}
# PRON: {'TP': 531, 'FP': 2, 'TN': 19176, 'FN': 33}
# NUM: {'TP': 279, 'FP': 1, 'TN': 19348, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19707, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1182 counts.
# Tag with the most false negative is:  ADJ with 605 counts.
# confusion_matrices: {'DET': {'TP': 2368, 'FP': 186, 'TN': 17164, 'FN': 24}, 'NOUN': {'TP': 4953, 'FP': 1182, 'TN': 13455, 'FN': 152}, 'ADJ': {'TP': 976, 'FP': 91, 'TN': 18070, 'FN': 605}, 'VERB': {'TP': 2271, 'FP': 103, 'TN': 16816, 'FN': 552}, 'ADP': {'TP': 2428, 'FP': 496, 'TN': 16790, 'FN': 28}, '.': {'TP': 2421, 'FP': 13, 'TN': 17308, 'FN': 0}, 'ADV': {'TP': 607, 'FP': 17, 'TN': 18860, 'FN': 258}, 'CONJ': {'TP': 578, 'FP': 2, 'TN': 19146, 'FN': 16}, 'PRT': {'TP': 225, 'FP': 8, 'TN': 19221, 'FN': 288}, 'PRON': {'TP': 531, 'FP': 2, 'TN': 19176, 'FN': 33}, 'NUM': {'TP': 279, 'FP': 1, 'TN': 19348, 'FN': 114}, 'X': {'TP': 4, 'FP': 0, 'TN': 19707, 'FN': 31}}
# sentence:       ['Several', 'police', 'cars', ',', 'loaded', 'with', 'armed', 'officers', ',', 'raced', 'alongside', ',', 'blazing', 'away', 'at', 'the', 'tires', 'of', 'the', 'big', 'jet', '.']
# hidden s:       ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'ADV', '.', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'VERB', 'NOUN', '.', 'NOUN', 'ADP', '.', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.']
# DET: {'TP': 2370, 'FP': 186, 'TN': 17184, 'FN': 24}
# NOUN: {'TP': 4958, 'FP': 1183, 'TN': 13471, 'FN': 152}
# ADJ: {'TP': 978, 'FP': 91, 'TN': 18090, 'FN': 605}
# VERB: {'TP': 2274, 'FP': 103, 'TN': 16834, 'FN': 553}
# ADP: {'TP': 2431, 'FP': 497, 'TN': 16808, 'FN': 28}
# .: {'TP': 2425, 'FP': 13, 'TN': 17326, 'FN': 0}
# ADV: {'TP': 608, 'FP': 17, 'TN': 18880, 'FN': 259}
# CONJ: {'TP': 578, 'FP': 2, 'TN': 19168, 'FN': 16}
# PRT: {'TP': 225, 'FP': 8, 'TN': 19243, 'FN': 288}
# PRON: {'TP': 531, 'FP': 2, 'TN': 19198, 'FN': 33}
# NUM: {'TP': 279, 'FP': 1, 'TN': 19370, 'FN': 114}
# X: {'TP': 4, 'FP': 0, 'TN': 19729, 'FN': 31}
#
# Tag with the most false positives is: NOUN with 1183 counts.
# ...
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# DET: {'TP': 2954, 'FP': 240, 'TN': 21748, 'FN': 29}
# NOUN: {'TP': 6351, 'FP': 1456, 'TN': 16965, 'FN': 199}
# ADJ: {'TP': 1257, 'FP': 121, 'TN': 22863, 'FN': 730}
# VERB: {'TP': 2892, 'FP': 128, 'TN': 21251, 'FN': 700}
# ADP: {'TP': 3129, 'FP': 628, 'TN': 21181, 'FN': 33}
# .: {'TP': 3067, 'FP': 14, 'TN': 21890, 'FN': 0}
# ADV: {'TP': 747, 'FP': 18, 'TN': 23880, 'FN': 326}
# CONJ: {'TP': 709, 'FP': 3, 'TN': 24243, 'FN': 16}
# PRT: {'TP': 289, 'FP': 12, 'TN': 24301, 'FN': 369}
# PRON: {'TP': 606, 'FP': 2, 'TN': 24318, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24488, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24930, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1456 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# confusion_matrices: {'DET': {'TP': 2954, 'FP': 240, 'TN': 21748, 'FN': 29}, 'NOUN': {'TP': 6351, 'FP': 1456, 'TN': 16965, 'FN': 199}, 'ADJ': {'TP': 1257, 'FP': 121, 'TN': 22863, 'FN': 730}, 'VERB': {'TP': 2892, 'FP': 128, 'TN': 21251, 'FN': 700}, 'ADP': {'TP': 3129, 'FP': 628, 'TN': 21181, 'FN': 33}, '.': {'TP': 3067, 'FP': 14, 'TN': 21890, 'FN': 0}, 'ADV': {'TP': 747, 'FP': 18, 'TN': 23880, 'FN': 326}, 'CONJ': {'TP': 709, 'FP': 3, 'TN': 24243, 'FN': 16}, 'PRT': {'TP': 289, 'FP': 12, 'TN': 24301, 'FN': 369}, 'PRON': {'TP': 606, 'FP': 2, 'TN': 24318, 'FN': 45}, 'NUM': {'TP': 343, 'FP': 1, 'TN': 24488, 'FN': 139}, 'X': {'TP': 4, 'FP': 0, 'TN': 24930, 'FN': 37}}
# sentence:       ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# hidden s:       ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2957, 'FP': 240, 'TN': 21763, 'FN': 29}
# NOUN: {'TP': 6355, 'FP': 1457, 'TN': 16978, 'FN': 199}
# ADJ: {'TP': 1258, 'FP': 121, 'TN': 22880, 'FN': 730}
# VERB: {'TP': 2896, 'FP': 128, 'TN': 21265, 'FN': 700}
# ADP: {'TP': 3131, 'FP': 629, 'TN': 21196, 'FN': 33}
# .: {'TP': 3068, 'FP': 14, 'TN': 21907, 'FN': 0}
# ADV: {'TP': 747, 'FP': 18, 'TN': 23897, 'FN': 327}
# CONJ: {'TP': 709, 'FP': 3, 'TN': 24261, 'FN': 16}
# PRT: {'TP': 289, 'FP': 12, 'TN': 24318, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24335, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24506, 'FN': 139}
# X: {'TP': 4, 'FP': 0, 'TN': 24948, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1457 counts.
# Tag with the most false negative is:  ADJ with 730 counts.
# confusion_matrices: {'DET': {'TP': 2957, 'FP': 240, 'TN': 21763, 'FN': 29}, 'NOUN': {'TP': 6355, 'FP': 1457, 'TN': 16978, 'FN': 199}, 'ADJ': {'TP': 1258, 'FP': 121, 'TN': 22880, 'FN': 730}, 'VERB': {'TP': 2896, 'FP': 128, 'TN': 21265, 'FN': 700}, 'ADP': {'TP': 3131, 'FP': 629, 'TN': 21196, 'FN': 33}, '.': {'TP': 3068, 'FP': 14, 'TN': 21907, 'FN': 0}, 'ADV': {'TP': 747, 'FP': 18, 'TN': 23897, 'FN': 327}, 'CONJ': {'TP': 709, 'FP': 3, 'TN': 24261, 'FN': 16}, 'PRT': {'TP': 289, 'FP': 12, 'TN': 24318, 'FN': 370}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24335, 'FN': 45}, 'NUM': {'TP': 343, 'FP': 1, 'TN': 24506, 'FN': 139}, 'X': {'TP': 4, 'FP': 0, 'TN': 24948, 'FN': 37}}
# sentence:       ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# hidden s:       ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'NUM', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'ADP', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
# DET: {'TP': 2959, 'FP': 240, 'TN': 21785, 'FN': 29}
# NOUN: {'TP': 6361, 'FP': 1459, 'TN': 16994, 'FN': 199}
# ADJ: {'TP': 1259, 'FP': 121, 'TN': 22902, 'FN': 731}
# VERB: {'TP': 2897, 'FP': 128, 'TN': 21288, 'FN': 700}
# ADP: {'TP': 3135, 'FP': 631, 'TN': 21214, 'FN': 33}
# .: {'TP': 3071, 'FP': 14, 'TN': 21928, 'FN': 0}
# ADV: {'TP': 748, 'FP': 18, 'TN': 23919, 'FN': 328}
# CONJ: {'TP': 710, 'FP': 3, 'TN': 24284, 'FN': 16}
# PRT: {'TP': 290, 'FP': 12, 'TN': 24341, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24359, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24528, 'FN': 141}
# X: {'TP': 4, 'FP': 0, 'TN': 24972, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1459 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# confusion_matrices: {'DET': {'TP': 2959, 'FP': 240, 'TN': 21785, 'FN': 29}, 'NOUN': {'TP': 6361, 'FP': 1459, 'TN': 16994, 'FN': 199}, 'ADJ': {'TP': 1259, 'FP': 121, 'TN': 22902, 'FN': 731}, 'VERB': {'TP': 2897, 'FP': 128, 'TN': 21288, 'FN': 700}, 'ADP': {'TP': 3135, 'FP': 631, 'TN': 21214, 'FN': 33}, '.': {'TP': 3071, 'FP': 14, 'TN': 21928, 'FN': 0}, 'ADV': {'TP': 748, 'FP': 18, 'TN': 23919, 'FN': 328}, 'CONJ': {'TP': 710, 'FP': 3, 'TN': 24284, 'FN': 16}, 'PRT': {'TP': 290, 'FP': 12, 'TN': 24341, 'FN': 370}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24359, 'FN': 45}, 'NUM': {'TP': 343, 'FP': 1, 'TN': 24528, 'FN': 141}, 'X': {'TP': 4, 'FP': 0, 'TN': 24972, 'FN': 37}}
# sentence:       ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# hidden s:       ['ADP', 'NOUN', 'NOUN', '.', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2961, 'FP': 241, 'TN': 21812, 'FN': 29}
# NOUN: {'TP': 6372, 'FP': 1461, 'TN': 17011, 'FN': 199}
# ADJ: {'TP': 1260, 'FP': 121, 'TN': 22931, 'FN': 731}
# VERB: {'TP': 2900, 'FP': 128, 'TN': 21315, 'FN': 700}
# ADP: {'TP': 3143, 'FP': 631, 'TN': 21236, 'FN': 33}
# .: {'TP': 3073, 'FP': 14, 'TN': 21956, 'FN': 0}
# ADV: {'TP': 748, 'FP': 18, 'TN': 23949, 'FN': 328}
# CONJ: {'TP': 710, 'FP': 3, 'TN': 24314, 'FN': 16}
# PRT: {'TP': 290, 'FP': 12, 'TN': 24371, 'FN': 370}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24389, 'FN': 45}
# NUM: {'TP': 343, 'FP': 1, 'TN': 24555, 'FN': 144}
# X: {'TP': 4, 'FP': 0, 'TN': 25002, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1461 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# confusion_matrices: {'DET': {'TP': 2961, 'FP': 241, 'TN': 21812, 'FN': 29}, 'NOUN': {'TP': 6372, 'FP': 1461, 'TN': 17011, 'FN': 199}, 'ADJ': {'TP': 1260, 'FP': 121, 'TN': 22931, 'FN': 731}, 'VERB': {'TP': 2900, 'FP': 128, 'TN': 21315, 'FN': 700}, 'ADP': {'TP': 3143, 'FP': 631, 'TN': 21236, 'FN': 33}, '.': {'TP': 3073, 'FP': 14, 'TN': 21956, 'FN': 0}, 'ADV': {'TP': 748, 'FP': 18, 'TN': 23949, 'FN': 328}, 'CONJ': {'TP': 710, 'FP': 3, 'TN': 24314, 'FN': 16}, 'PRT': {'TP': 290, 'FP': 12, 'TN': 24371, 'FN': 370}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24389, 'FN': 45}, 'NUM': {'TP': 343, 'FP': 1, 'TN': 24555, 'FN': 144}, 'X': {'TP': 4, 'FP': 0, 'TN': 25002, 'FN': 37}}
# sentence:       ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# hidden s:       ['CONJ', 'PRT', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# predictions:    ['CONJ', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# DET: {'TP': 2963, 'FP': 241, 'TN': 21832, 'FN': 29}
# NOUN: {'TP': 6376, 'FP': 1462, 'TN': 17028, 'FN': 199}
# ADJ: {'TP': 1262, 'FP': 121, 'TN': 22951, 'FN': 731}
# VERB: {'TP': 2902, 'FP': 128, 'TN': 21335, 'FN': 700}
# ADP: {'TP': 3147, 'FP': 632, 'TN': 21253, 'FN': 33}
# .: {'TP': 3074, 'FP': 14, 'TN': 21977, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 23970, 'FN': 328}
# CONJ: {'TP': 712, 'FP': 3, 'TN': 24334, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24391, 'FN': 371}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24411, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24575, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25024, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1462 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# confusion_matrices: {'DET': {'TP': 2963, 'FP': 241, 'TN': 21832, 'FN': 29}, 'NOUN': {'TP': 6376, 'FP': 1462, 'TN': 17028, 'FN': 199}, 'ADJ': {'TP': 1262, 'FP': 121, 'TN': 22951, 'FN': 731}, 'VERB': {'TP': 2902, 'FP': 128, 'TN': 21335, 'FN': 700}, 'ADP': {'TP': 3147, 'FP': 632, 'TN': 21253, 'FN': 33}, '.': {'TP': 3074, 'FP': 14, 'TN': 21977, 'FN': 0}, 'ADV': {'TP': 749, 'FP': 18, 'TN': 23970, 'FN': 328}, 'CONJ': {'TP': 712, 'FP': 3, 'TN': 24334, 'FN': 16}, 'PRT': {'TP': 291, 'FP': 12, 'TN': 24391, 'FN': 371}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24411, 'FN': 45}, 'NUM': {'TP': 344, 'FP': 1, 'TN': 24575, 'FN': 145}, 'X': {'TP': 4, 'FP': 0, 'TN': 25024, 'FN': 37}}
# sentence:       ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'VERB', 'NOUN', '.']
# DET: {'TP': 2966, 'FP': 242, 'TN': 21860, 'FN': 29}
# NOUN: {'TP': 6386, 'FP': 1463, 'TN': 17049, 'FN': 199}
# ADJ: {'TP': 1262, 'FP': 121, 'TN': 22983, 'FN': 731}
# VERB: {'TP': 2905, 'FP': 128, 'TN': 21363, 'FN': 701}
# ADP: {'TP': 3154, 'FP': 633, 'TN': 21277, 'FN': 33}
# .: {'TP': 3079, 'FP': 14, 'TN': 22004, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24001, 'FN': 329}
# CONJ: {'TP': 713, 'FP': 3, 'TN': 24365, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24422, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24443, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24607, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25056, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1463 counts.
# Tag with the most false negative is:  ADJ with 731 counts.
# confusion_matrices: {'DET': {'TP': 2966, 'FP': 242, 'TN': 21860, 'FN': 29}, 'NOUN': {'TP': 6386, 'FP': 1463, 'TN': 17049, 'FN': 199}, 'ADJ': {'TP': 1262, 'FP': 121, 'TN': 22983, 'FN': 731}, 'VERB': {'TP': 2905, 'FP': 128, 'TN': 21363, 'FN': 701}, 'ADP': {'TP': 3154, 'FP': 633, 'TN': 21277, 'FN': 33}, '.': {'TP': 3079, 'FP': 14, 'TN': 22004, 'FN': 0}, 'ADV': {'TP': 749, 'FP': 18, 'TN': 24001, 'FN': 329}, 'CONJ': {'TP': 713, 'FP': 3, 'TN': 24365, 'FN': 16}, 'PRT': {'TP': 291, 'FP': 12, 'TN': 24422, 'FN': 372}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24443, 'FN': 45}, 'NUM': {'TP': 344, 'FP': 1, 'TN': 24607, 'FN': 145}, 'X': {'TP': 4, 'FP': 0, 'TN': 25056, 'FN': 37}}
# sentence:       ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# hidden s:       ['ADJ', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', '.']
# DET: {'TP': 2966, 'FP': 242, 'TN': 21869, 'FN': 30}
# NOUN: {'TP': 6389, 'FP': 1464, 'TN': 17055, 'FN': 199}
# ADJ: {'TP': 1263, 'FP': 121, 'TN': 22991, 'FN': 732}
# VERB: {'TP': 2907, 'FP': 128, 'TN': 21371, 'FN': 701}
# ADP: {'TP': 3154, 'FP': 634, 'TN': 21286, 'FN': 33}
# .: {'TP': 3080, 'FP': 14, 'TN': 22013, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24011, 'FN': 329}
# CONJ: {'TP': 714, 'FP': 3, 'TN': 24374, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24432, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24453, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24617, 'FN': 145}
# X: {'TP': 4, 'FP': 0, 'TN': 25066, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1464 counts.
# Tag with the most false negative is:  ADJ with 732 counts.
# confusion_matrices: {'DET': {'TP': 2966, 'FP': 242, 'TN': 21869, 'FN': 30}, 'NOUN': {'TP': 6389, 'FP': 1464, 'TN': 17055, 'FN': 199}, 'ADJ': {'TP': 1263, 'FP': 121, 'TN': 22991, 'FN': 732}, 'VERB': {'TP': 2907, 'FP': 128, 'TN': 21371, 'FN': 701}, 'ADP': {'TP': 3154, 'FP': 634, 'TN': 21286, 'FN': 33}, '.': {'TP': 3080, 'FP': 14, 'TN': 22013, 'FN': 0}, 'ADV': {'TP': 749, 'FP': 18, 'TN': 24011, 'FN': 329}, 'CONJ': {'TP': 714, 'FP': 3, 'TN': 24374, 'FN': 16}, 'PRT': {'TP': 291, 'FP': 12, 'TN': 24432, 'FN': 372}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24453, 'FN': 45}, 'NUM': {'TP': 344, 'FP': 1, 'TN': 24617, 'FN': 145}, 'X': {'TP': 4, 'FP': 0, 'TN': 25066, 'FN': 37}}
# sentence:       ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']
# hidden s:       ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NUM', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', '.', 'VERB', '.', '.', '.']
# predictions:    ['DET', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'VERB', '.', '.', '.']
# DET: {'TP': 2970, 'FP': 242, 'TN': 21897, 'FN': 30}
# NOUN: {'TP': 6395, 'FP': 1469, 'TN': 17076, 'FN': 199}
# ADJ: {'TP': 1264, 'FP': 121, 'TN': 23019, 'FN': 735}
# VERB: {'TP': 2909, 'FP': 128, 'TN': 21401, 'FN': 701}
# ADP: {'TP': 3158, 'FP': 634, 'TN': 21314, 'FN': 33}
# .: {'TP': 3089, 'FP': 14, 'TN': 22036, 'FN': 0}
# ADV: {'TP': 749, 'FP': 18, 'TN': 24043, 'FN': 329}
# CONJ: {'TP': 715, 'FP': 3, 'TN': 24405, 'FN': 16}
# PRT: {'TP': 291, 'FP': 12, 'TN': 24464, 'FN': 372}
# PRON: {'TP': 607, 'FP': 2, 'TN': 24485, 'FN': 45}
# NUM: {'TP': 344, 'FP': 1, 'TN': 24647, 'FN': 147}
# X: {'TP': 4, 'FP': 0, 'TN': 25098, 'FN': 37}
#
# Tag with the most false positives is: NOUN with 1469 counts.
# Tag with the most false negative is:  ADJ with 735 counts.
# confusion_matrices: {'DET': {'TP': 2970, 'FP': 242, 'TN': 21897, 'FN': 30}, 'NOUN': {'TP': 6395, 'FP': 1469, 'TN': 17076, 'FN': 199}, 'ADJ': {'TP': 1264, 'FP': 121, 'TN': 23019, 'FN': 735}, 'VERB': {'TP': 2909, 'FP': 128, 'TN': 21401, 'FN': 701}, 'ADP': {'TP': 3158, 'FP': 634, 'TN': 21314, 'FN': 33}, '.': {'TP': 3089, 'FP': 14, 'TN': 22036, 'FN': 0}, 'ADV': {'TP': 749, 'FP': 18, 'TN': 24043, 'FN': 329}, 'CONJ': {'TP': 715, 'FP': 3, 'TN': 24405, 'FN': 16}, 'PRT': {'TP': 291, 'FP': 12, 'TN': 24464, 'FN': 372}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24485, 'FN': 45}, 'NUM': {'TP': 344, 'FP': 1, 'TN': 24647, 'FN': 147}, 'X': {'TP': 4, 'FP': 0, 'TN': 25098, 'FN': 37}}
#
# model got 22495 samples correct out of 25139
# accuracy: 0.8948247742551414
# Error rate for the HMM model: 0.10517522574485859
# Error rate for the most frequent tag baseline: 0.7376983969131629

# %% [markdown]
# # **Analyze**

# %% [markdown]
# First, let's look at the confusion matrix for each tag. The confusion matrix shows the number of true positives (TP), false positives (FP), true negatives (TN), and false negatives (FN) for each tag.
#
# The tag with the most false positives is NOUN, with 1469 false positives. This means that the model often mistakes other tags for NOUN.
# The tag with the most false negatives is ADJ, with 735 false negatives. This means that the model often fails to tag words as ADJ when it should.
# Next, let's look at the sentence and the predicted tags. We can see that the model made some mistakes in this sentence. For example, the word "one" is tagged as NOUN instead of NUM, and the word "reasons" is tagged as NOUN instead of VERB. These mistakes may be due to the fact that the model is based on probabilities and is not always accurate.
#
# Overall, the model seems to perform well for some tags, such as DET, VERB, ADP, ., ADV, CONJ, PRT, PRON, and NUM, which have high true positive rates and low false positive and false negative rates. However, the model struggles with NOUN and ADJ, which have high false positive and false negative rates. This may be due to the fact that NOUN and ADJ are more ambiguous tags that can be confused with other tags.
#
# To improve the performance of the model, we could consider using a more complex model, such as a conditional random field (CRF) or a recurrent neural network (RNN), which can capture more complex dependencies between tags. We could also consider using additional features, such as word shape or context, to improve the accuracy of the model.

# %% [markdown]
# # **For Last Output:**

# %%
def calculate_metrics(confusion_matrix):
    metrics = {}
    for tag, values in confusion_matrix.items():
        tp = values['TP']
        fp = values['FP']
        tn = values['TN']
        fn = values['FN']

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        metrics[tag] = {'precision': precision, 'recall': recall, 'f1_score': f1_score}

    return metrics

# %%
confusion_matrices = {'DET': {'TP': 2970, 'FP': 242, 'TN': 21897, 'FN': 30}, 'NOUN': {'TP': 6395, 'FP': 1469, 'TN': 17076, 'FN': 199}, 'ADJ': {'TP': 1264, 'FP': 121, 'TN': 23019, 'FN': 735}, 'VERB': {'TP': 2909, 'FP': 128, 'TN': 21401, 'FN': 701}, 'ADP': {'TP': 3158, 'FP': 634, 'TN': 21314, 'FN': 33}, '.': {'TP': 3089, 'FP': 14, 'TN': 22036, 'FN': 0}, 'ADV': {'TP': 749, 'FP': 18, 'TN': 24043, 'FN': 329}, 'CONJ': {'TP': 715, 'FP': 3, 'TN': 24405, 'FN': 16}, 'PRT': {'TP': 291, 'FP': 12, 'TN': 24464, 'FN': 372}, 'PRON': {'TP': 607, 'FP': 2, 'TN': 24485, 'FN': 45}, 'NUM': {'TP': 344, 'FP': 1, 'TN': 24647, 'FN': 147}, 'X': {'TP': 4, 'FP': 0, 'TN': 25098, 'FN': 37}}

metrics = calculate_metrics(confusion_matrices)

sorted_tags = sorted(metrics.items(), key=lambda x: x[1]['f1_score'])

lowest_f1_tags = [tag[0] for tag in sorted_tags[:3]]
print(f"Tags with the lowest F1-scores (most frequent errors): {lowest_f1_tags}")
# Out:
# Tags with the lowest F1-scores (most frequent errors): ['X', 'PRT', 'ADJ']
