# %% [markdown]
# # IUST Computer Engineering Department 🏫
# ## Introduction to Natural Language Processing 📚 (The Final Project)
# -------------------------------------------------------------------------------<br>
#
# ## Navid Ebrahimi
# The objective of this project is to acquaint you with the fundamentals of Retrieval Augmented Generation (RAG). Be sure to explore various options and address challenges in a creative manner. 🎯
#
# **Project Guidelines** 📝
# - Avoid cheating at all costs. If a set of submissions is found to be [plagiarized](https://translate.google.as/?sl=en&tl=fa&text=Very%20hard%20word%2C%20I%20know%2C%20here%27s%20the%20meaning%3A%0Aplagiarized&op=translate), only one will be randomly chosen for grading. The others will fail the project. ❌
# - You are allowed to use any document, article, paper, or video as a resource for writing your code, provided you include a link to the material used. 📖
# - The use of Language Learning Models (LLMs), ChatBots, and Copilots is encouraged. If you utilize any of these tools, make sure to attach the chat history that led you to the answer to your question, or the code, to this .ipynb document. (You must provide the entire chat, not just the final answer or your initial prompt.) 💻
# - You may not submit any additional documents, files, etc., along with this document. Only solutions, codes, explanations, etc., in this document will be graded. 📄
# - You are required to implement everything (except the Language Modeling parts) from scratch. The use of libraries like langchain, llama_index, etc., is not permitted for this purpose. 🚫
# - Please adhere to the code guidelines provided throughout the documents. 📝 I’ve spent time in a library 📚 crafting all of this, so if you overlook them, you’ll lose the points allocated for that section. ❌
# - We need to use GPUs for this assignment, don't forget to turn on GPU usage for your notebook session.
#
# -------------------------------------------------------------------------------<br>
# # Alright, let's get started. 🚀

# %% [markdown]
# ## What is RAG? 🤔
# We've all used ChatGPT and experienced moments when it starts to generate content that is often incorrect or unrelated to our query. Do you know why this happens? These Large Language Models (LLMs) are not magical entities; they are simply models trained on a vast amount of text. 📚 You could even consider a significant portion of the internet. However, this is not all the data available in the world, because data is not a static concept. You yourself generate some data every day through your use of the Internet, Social Media, and so on. 🌐💻📱
#
# So, no matter how much data you use to train your LLM, you always end up encountering new data. This is one of the reasons behind the famous ChatGPT response that tells you it only knows things up to a certain date. 📅 Also, these models tend to hallucinate too. It means they provide incorrect answers but in a very convincing manner. 🎭
#
# On the other hand, we have retrieval techniques. Don't worry if it sounds complicated (it actually isn't easy, you may need to take a course to familiarize yourself with these concepts 😅, but that's not necessary for this project), but you use it on a daily basis. You can think of Search Engines (like Google, for example) as a complex form of information retrieval. 🔍
#
# So, one day, people came up with this idea that it would be cool if ChatGPT could search Google for us, read the articles for us, summarize what it read, and tell us that. 📖 So, this is not exactly what RAG is, but it's something similar. We have a corpus (a large amount of data) and a query (what a user typed as input). Now, we search through this corpus using techniques related to vectors and vector databases, and find the most similar items in our corpus to the query. Then, we pass these items to an LLM and ask for a structured, well-formatted, user-friendly output. 📈📊

# %% [markdown]
# ## I'm Interested in the Technical Details, What Should I Read? 📚🔍
# - I strongly recommend reading the [original RAG paper](https://arxiv.org/abs/2005.11401). If you need help understanding the paper or have any questions about it, feel free to reach out to me via Telegram or find me on the second floor of the department in the NLP lab on Sundays and Tuesdays. 📖
# - There appears to be a [comprehensive 2.5-hour course](https://www.freecodecamp.org/news/mastering-rag-from-scratch/) available. I haven't personally watched it, but if you find a better one, let me know so I can update this document. 🎥
# - Here is [an article](https://www.smashingmagazine.com/2024/01/guide-retrieval-augmented-generation-language-models/) that explains the concepts very well. Initially, I wanted to use this article as the basis for this project, but unfortunately, the llama_index library used in the article seems to be outdated, so most of the code would need to be rewritten. On second thought, I found it more useful to focus on core concepts rather than learning specific libraries. You might want to check out some libraries like langchain or llama_index which provide a lot of tools for RAG. (But not for this project) 📝💡
# - Don't hesitate to use Google, ask chatbots about any new concepts and terms. If you use search engine-aware chatbots like Microsoft Copilot, they provide links for each part of their answers which is useful if you want to delve deeper into that part. 🌐🤖
# - Lastly, we have [the article](https://learnbybuilding.ai/tutorials/rag-from-scratch) that serves as the foundation for this project. 📚🔍

# %% [markdown]
# # Learn
# First, we’re going to go through a simple RAG implementation. It’s going to be similar to the article, except for the (LLM) part. For that, I’m going to use Hugging Face. 🤗 I’ll also try to explain the code in simple terms, but feel free to read the article if you prefer their writing style.

# %% [markdown]
# ## Let's Install the Necessary Libraries 📚🔧
# Did you know that using the `--quiet` or `-q` option with the `pip install` command minimizes the output displayed on your screen? 🖥️ This can make your terminal less cluttered. Also, using `-U` will upgrade the libraries if they were previously installed. This is particularly useful for certain libraries like `transformers` that are frequently updated. 🔄

# %%
# !pip install -U accelerate transformers --quiet

# %% [markdown]
# ## Gather a Corpus 📚
# Technically, a corpus refers to a large and structured set of texts. However, for the sake of our discussion, let’s consider our collection as a “corpus”, even though it might not be large in the traditional sense. 😉

# %%
corpus_of_documents = [
    "Take a leisurely walk in the park and enjoy the fresh air.",
    "Visit a local museum and discover something new.",
    "Attend a live music concert and feel the rhythm.",
    "Go for a hike and admire the natural scenery.",
    "Have a picnic with friends and share some laughs.",
    "Explore a new cuisine by dining at an ethnic restaurant.",
    "Take a yoga class and stretch your body and mind.",
    "Join a local sports league and enjoy some friendly competition.",
    "Attend a workshop or lecture on a topic you're interested in.",
    "Visit an amusement park and ride the roller coasters."
]

# %% [markdown]
# ## Create a Retriever 🕵️‍♂️
# Now, we’re going to create a simple retriever. The role of the retriever is to compare the user’s query with a large corpus of text and find those that are most similar in context. (You know what context is by now, don’t you? 😊 If you’ve forgotten, refer back to your initial lectures). For now, let’s say we want to find similar text based on simple similarity metrics. The code is straightforward, and I have faith in you, chief! Dive into the code. 👨‍💻

# %%
def jaccard_similarity(query, document):
    query = query.lower().split(" ")
    document = document.lower().split(" ")
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return len(intersection)/len(union)

# %% [markdown]
# Hey, you may want to look at wikipedia page for [Jaccard Similarity](https://en.wikipedia.org/wiki/Jaccard_index).

# %%
def return_response(query, corpus):
    similarities = []
    for doc in corpus:
        similarity = jaccard_similarity(user_input, doc)
        similarities.append(similarity)
    return corpus_of_documents[similarities.index(max(similarities))]

# %% [markdown]
# ## Create a Generator 🖥️
# Now, we’re going to create a generator. This will help us compile the information retrieved into a well-structured and user-friendly text.

# %% [markdown]
# OK, let's say in a senario, we ask user what they like to do, the their answer is this:

# %%
user_input = "I like to hike"

# %% [markdown]
# Now by using the retrieval model I find this activity that best fits this user.

# %%
relevant_document = return_response(user_input, corpus_of_documents)
print(relevant_document)
# Out:
# Go for a hike and admire the natural scenery.

# %% [markdown]
# The answer seems good enough, but we can do better, yeah?

# %% [markdown]
# Let’s import a Language Model. I’m going to try out Microsoft Phi-3 because it recently hit the market, and I haven’t had a chance to try it for myself yet. So, I’m seizing this opportunity to do so! 😊👨‍💻

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %% [markdown]
# Downloading the model gonna take a while, use this time to rest your eyes for a bit. 😊👀💤

# %%
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-128k-instruct")

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

# %% [markdown]
# Now we try to get the LLM to become our generator. We simply place the retrieved information and user query in the following prompt and ask the model for well formatted text.

# %%
prompt = """You are a bot that makes recommendations for activities. Try to be helpful recommender system.
This is the recommended activity: {relevant_document}
The user input is: {user_input}
Compile a recommendation to the user based on the recommended activity and the user input."""

# %%
prompt = prompt.replace("{relevant_document}", relevant_document).replace("{user_input}", user_input)
print(prompt)
# Out:
# You are a bot that makes recommendations for activities. Try to be helpful recommender system.
# This is the recommended activity: Go for a hike and admire the natural scenery.
# The user input is: I like to hike
# Compile a recommendation to the user based on the recommended activity and the user input.

# %%
messages = [
    {"role": "user", "content": prompt},
]

# %%
prompt
# Out:
# 'You are a bot that makes recommendations for activities. Try to be helpful recommender system.\nThis is the recommended activity: doctor: depends on severity. covid-19 pandemic at this time, so a doctor on video may consult by video instead of requiring an in-person visit. flu-like symptoms can be from a strep throat infection, a cold or influenza, or from some other cause like covid-19. usually, a person calls the doctor if the symptoms are bothersome, serious, recurrent, or persistent. covid-19 testing depends on local availability. (3/22/20)\nThe user input is: What are the symptoms of COVID-19?\nCompile a recommendation to the user based on the recommended activity and the user input.'

# %% [markdown]
# Here's the augmented generated text

# %%
output = pipe(messages, **generation_args)
print(output[0]['generated_text'])
# Out:
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.30e8c65610d4d676914372eaf89dcb0cf15a21d6.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
#  Based on your query about the symptoms of COVID-19, it would be beneficial for you to consult with a healthcare professional. Given the current COVID-19 pandemic, many doctors are offering video consultations to ensure everyone's safety. This allows you to discuss your concerns and get accurate information without the need for an in-person visit. Symptoms of COVID-19 can include fever, cough, and difficulty breathing among others. However, it's important to remember that these symptoms can also be associated with other illnesses like the flu or a common cold. Therefore, a healthcare professional can provide the most accurate advice based on your specific situation.

# %% [markdown]
# ## Very Cool, but Not Perfect! 😎👌
# Alright, you’ve just seen a very basic example of RAG. However, there are some issues present. The corpus is small, and the documents in the corpus are short sentences, which causes the Language Model (LM) to generate some text on its own. 📚🤖
#
# Also, our retriever is not very efficient and it may encounter bugs in some cases. For instance, even when users specify that they are not interested in a certain activity, the retriever might still bring up that activity for them. 🐜🔍
#
# So, in this project, you’re going to address some of these issues. The rest of this document consists of some empty cells and tips for you on how to fill them with code. Let’s get coding! 👨‍💻🚀

# %% [markdown]
# # The Project

# %% [markdown]
# ## Determine Your Task 🎯
# What do you aim to implement with RAG? A recommender system? 🎁 A chatbot for a website’s FAQ? 💬 A medical advisor? 🩺 Or perhaps something else entirely?
#
# Specify your objective in this cell.

# %%
task_title = "A medical advisor"
url_for_more_information = "https://medium.com/@mohdzeesh2002/dr-insights-build-your-own-llm-rag-medical-advisor-using-langchain-mistral-and-chromadb-9b678143ecbd"

print(f"My task is: {task_title}")
print(f'For more information see: {url_for_more_information}')
# Out:
# My task is: A medical advisor
# For more information see: https://medium.com/@mohdzeesh2002/dr-insights-build-your-own-llm-rag-medical-advisor-using-langchain-mistral-and-chromadb-9b678143ecbd

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## 🧐 Find or gather a corpus
# Remember the fake corpus? 📚 It’s time to switch things up and use something real. 🌐 You need to use a dataset from  [huggingface datasets](https://huggingface.co/datasets) for this project. 🚀 Don’t use files that are outside of this notebook, this notebook should be able to run on its own without depending on anything external. 💻👍

# %%
# !pip install tensorflow-datasets -q
# !pip install datasets -q
# !pip install tqdm -q
# !pip install transformers einops accelerate bitsandbytes -q
# !pip install openai -q
# !pip install tenacity -q

# %%
# !pip install datasets -q

# %%
from datasets import load_dataset, DatasetDict, concatenate_datasets

# %% [markdown]
# ### Medical Dialog Dataset

# %%
# Load your dataset
medical_dialog_dataset = DatasetDict({
    "train": load_dataset('medical_dialog', 'processed.en', split='train'),
    "validation": load_dataset('medical_dialog', 'processed.en', split='validation'),
    "test": load_dataset('medical_dialog', 'processed.en', split='test')
})
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for medical_dialog contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/medical_dialog
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
medical_dialog_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['description', 'utterances'],
#         num_rows: 482
#     })
#     validation: Dataset({
#         features: ['description', 'utterances'],
#         num_rows: 60
#     })
#     test: Dataset({
#         features: ['description', 'utterances'],
#         num_rows: 61
#     })
# })

# %%
medical_dialog_dataset['train']['utterances'][0]
# Out:
# ['patient: throat a bit sore and want to get a good imune booster, especially in light of the virus. please advise. have not been in contact with nyone with the virus.',
#  "doctor: during this pandemic. throat pain can be from a strep throat infection (antibiotics needed), a cold or influenza or other virus, or from some other cause such as allergies or irritants. usually, a person sees the doctor (call first) if the sore throat is bothersome, recurrent, or doesn't go away quickly. covid-19 infections tend to have cough, whereas strep throat usually lacks cough but has more throat pain. (3/21/20)"]

# %% [markdown]
# ### Medical Meadow Wikidoc Dataset

# %%
medical_meadow_wikidoc_dataset = load_dataset('medalpaca/medical_meadow_wikidoc')

# %%
medical_meadow_wikidoc_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output', 'instruction'],
#         num_rows: 10000
#     })
# })

# %%
medical_meadow_wikidoc_dataset['train'][0]
# Out:
# {'input': "Can you provide an overview of the lung's squamous cell carcinoma?",
#  'output': 'Squamous cell carcinoma of the lung may be classified according to the WHO histological classification system into 4 main types: papillary, clear cell, small cell, and basaloid.',
#  'instruction': 'Answer this question truthfully'}

# %% [markdown]
# ## 📝 Create some queries
# I want you to create 20 queries related to your task. You can use any Language Model you want for this matter, or if you’re feeling strong 💪 and have the time, write it yourself. 🖊️
#
# You need to create a Hugging Face account, format your 20 queries into the accepted dataset format for Hugging Face 🤗 and push it to your Hugging Face account. Be sure to make it public and use it for the evaluation task. 👀

# %%
import datasets
from datasets import Dataset
import pandas as pd

# Define the queries
queries = [
    "What are the symptoms of diabetes?",
    "How can I manage high blood pressure?",
    "What are the side effects of taking aspirin daily?",
    "Can you explain the causes of chronic back pain?",
    "What diet should I follow for heart health?",
    "How often should I get a general health check-up?",
    "What are the treatment options for asthma?",
    "Can stress cause physical illnesses?",
    "What are the early signs of Alzheimer's disease?",
    "How can I improve my mental health?",
    "What are the common symptoms of a stroke?",
    "How do I know if I have a food allergy?",
    "What is the best way to quit smoking?",
    "Can you explain the stages of cancer?",
    "What should I do if I have a high fever?",
    "How can I prevent the common cold?",
    "What are the symptoms of COVID-19?",
    "How is arthritis diagnosed and treated?",
    "What are the benefits of regular exercise?",
    "Can you explain the different types of headaches?"
]

# Create a pandas DataFrame
ds = datasets.Dataset.from_dict({'query': queries})

# %%
# !sudo apt-get install git-lfs -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !git config --global credential.helper store

# %%
# !huggingface-cli login

# %%
ds.push_to_hub('Navidium/Medical_Queries')

# %% [markdown]
# ## 🛠️ Create a Retriever
# To create your retriever, you need to use an encoder model. Something like BERT? Nah, BERT is so yesterday. Find something new and shiny! ✨ The basic idea is to encode every document (sentence) in your corpus into a vector space using the same encoder. Then, encode the user query into that same space. With some similarity metrics like dot product, you can find the most similar document to the user’s input and retrieve it. 🎯 You can train your own encoder if you have enough data and resources, 💪 or you can use one of those [ready-made on Hugging Face](https://huggingface.co/models?pipeline_tag=sentence-similarity&sort=trending), like these ones.

# %%
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

# %% [markdown]
# ### BioBERT Model

# %%
# Load the BioBERT tokenizer and model
biobert_tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
biobert_model = AutoModel.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
biobert_model = biobert_model.to(device)

# %% [markdown]
# ### MiniLML6 Model

# %%
# Load the miniLML6 tokenizer and model
miniLML6_tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
miniLML6_model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
miniLML6_model = miniLML6_model.to(device)

# %% [markdown]
# ### Select Model and Tokenizer

# %%
import numpy as np
import torch

batch_size = 32

model = miniLML6_model
tokenizer = miniLML6_tokenizer

# %% [markdown]
# ### Medical Dialog + Retriever

# %%
# Function to process a batch of utterances
def process_batch(model, tokenizer, batch):
    inputs_pa = tokenizer([item[0] for item in batch], padding=True, truncation=True, return_tensors="pt").to(device)
    inputs_do = tokenizer([item[1] for item in batch], padding=True, truncation=True, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs_pa = model(**inputs_pa)
        outputs_do = model(**inputs_do)

    embeddings_pa = outputs_pa.last_hidden_state.mean(dim=1).cpu().numpy()
    embeddings_do = outputs_do.last_hidden_state.mean(dim=1).cpu().numpy()

    return embeddings_pa, embeddings_do

# Iterate over the dataset in batches
embeddings_pa_list = []
embeddings_do_list = []

for i in tqdm(range(0, len(medical_dialog_dataset['train']), batch_size)):
    batch = medical_dialog_dataset['train']['utterances'][i:i + batch_size]
    embeddings_pa, embeddings_do = process_batch(model, tokenizer, batch)
    embeddings_pa_list.extend(embeddings_pa)
    embeddings_do_list.extend(embeddings_do)

# Convert the lists to numpy arrays if needed
embeddings_pa_array = np.array(embeddings_pa_list)
embeddings_do_array = np.array(embeddings_do_list)

# %% [markdown]
# ### Medical Meadow Wikidoc + Retriever

# %%
# Function to process a batch of utterances
def process_batch(model, tokenizer, batch):
    inputs_pa = tokenizer([item for item in batch['input']], padding=True, truncation=True, return_tensors="pt").to(device)
    inputs_do = tokenizer([item for item in batch['output']], padding=True, truncation=True, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs_pa = model(**inputs_pa)
        outputs_do = model(**inputs_do)

    embeddings_pa = outputs_pa.last_hidden_state.mean(dim=1).cpu().numpy()
    embeddings_do = outputs_do.last_hidden_state.mean(dim=1).cpu().numpy()

    return embeddings_pa, embeddings_do

# Iterate over the dataset in batches
embeddings_pa_list = []
embeddings_do_list = []

medical_meadow_wikidoc_dataset_size = len(medical_meadow_wikidoc_dataset['train'])
for i in tqdm(range(0, medical_meadow_wikidoc_dataset_size, batch_size)):
    batch = medical_meadow_wikidoc_dataset['train'][i:min(i + batch_size, medical_meadow_wikidoc_dataset_size)]
    embeddings_pa, embeddings_do = process_batch(model, tokenizer, batch)
    embeddings_pa_list.extend(embeddings_pa)
    embeddings_do_list.extend(embeddings_do)

# Convert the lists to numpy arrays if needed
embeddings_pa_array = np.array(embeddings_pa_list)
embeddings_do_array = np.array(embeddings_do_list)
# Out:
# 100%|██████████| 313/313 [00:53<00:00,  5.83it/s]

# %%
len(embeddings_pa_array)
# Out:
# 10000

# %%
query_inputs = tokenizer(queries, padding=True, truncation=True, return_tensors="pt").to(device)

with torch.no_grad():
    query_outputs = model(**query_inputs)

query_embeddings = query_outputs.last_hidden_state.mean(dim=1).cpu().numpy()

# %%
def compute_similarity(embeddings_pa, query_embeddings):
    embeddings_pa_norm = embeddings_pa / np.linalg.norm(embeddings_pa, axis=1, keepdims=True)
    query_embeddings_norm = query_embeddings / np.linalg.norm(query_embeddings, axis=1, keepdims=True)

    similarities = np.dot(query_embeddings_norm, embeddings_pa_norm.T)
    return similarities

similarity_scores = compute_similarity(embeddings_pa_array, query_embeddings)

most_similar_indices = np.argmax(similarity_scores, axis=1)

for i, query in enumerate(queries):
    most_similar_utterance_index = most_similar_indices[i]
    print(f"Query: {query}")
    print(f"Most similar utterance index: {most_similar_utterance_index}")
    print(f"Similarity score: {similarity_scores[i][most_similar_utterance_index]}")
    print()
# Out:
# Query: What are the symptoms of diabetes?
# Most similar utterance index: 9627
# Similarity score: 0.7933228015899658
#
# Query: How can I manage high blood pressure?
# Most similar utterance index: 3184
# Similarity score: 0.6937186121940613
#
# Query: What are the side effects of taking aspirin daily?
# Most similar utterance index: 2175
# Similarity score: 0.6134620904922485
#
# Query: Can you explain the causes of chronic back pain?
# Most similar utterance index: 1718
# Similarity score: 0.8491851091384888
#
# Query: What diet should I follow for heart health?
# Most similar utterance index: 294
# Similarity score: 0.6903603076934814
#
# Query: How often should I get a general health check-up?
# Most similar utterance index: 2701
# Similarity score: 0.3770182728767395
#
# Query: What are the treatment options for asthma?
# Most similar utterance index: 302
# Similarity score: 0.7672215104103088
#
# Query: Can stress cause physical illnesses?
# Most similar utterance index: 4699
# Similarity score: 0.7072659730911255
#
# Query: What are the early signs of Alzheimer's disease?
# Most similar utterance index: 4660
# Similarity score: 0.6560544967651367
#
# Query: How can I improve my mental health?
# Most similar utterance index: 3603
# Similarity score: 0.5429266691207886
#
# Query: What are the common symptoms of a stroke?
# Most similar utterance index: 2900
# Similarity score: 0.6779384016990662
#
# Query: How do I know if I have a food allergy?
# Most similar utterance index: 3240
# Similarity score: 0.6492377519607544
#
# Query: What is the best way to quit smoking?
# Most similar utterance index: 5152
# Similarity score: 0.515874445438385
#
# Query: Can you explain the stages of cancer?
# Most similar utterance index: 4828
# Similarity score: 0.7531462907791138
#
# Query: What should I do if I have a high fever?
# Most similar utterance index: 10
# Similarity score: 0.5512202978134155
#
# Query: How can I prevent the common cold?
# Most similar utterance index: 1821
# Similarity score: 0.6531519889831543
#
# Query: What are the symptoms of COVID-19?
# Most similar utterance index: 3778
# Similarity score: 0.6755133867263794
#
# Query: How is arthritis diagnosed and treated?
# Most similar utterance index: 1975
# Similarity score: 0.7411148548126221
#
# Query: What are the benefits of regular exercise?
# Most similar utterance index: 7760
# Similarity score: 0.5805010795593262
#
# Query: Can you explain the different types of headaches?
# Most similar utterance index: 8571
# Similarity score: 0.7369011044502258

# %% [markdown]
# ## 🎛️ Create a Generator
# For this part, I practically handed you the whole code on a silver platter. 🍽️ But since we know you’re an explorer at heart and love trying new things, you can’t use the model I previously used. 😈 You have to try 3 different generators and compare them based on the quality of their answers. 🧪📊 [These might come in handy](https://huggingface.co/models?pipeline_tag=text-generation&sort=trending).

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, AutoConfig, BitsAndBytesConfig
import json

# %% [markdown]
# ### **Structure of Models**

# %%
def create_pipeline(model, tokenizer):
  pipe = pipeline(
    "text-generation",
      model=model,
      tokenizer=tokenizer,
      torch_dtype=torch.bfloat16,
      trust_remote_code=True,
      device_map="auto",
  )
  return pipe

# %%
def create_prompt(relevant_document, user_input):
    prompt = f"{relevant_document}\n\nQuestion: {user_input}\n\nAs a health advisor, give your advice below:\n"
    return prompt

# %%
def generator_model(model_name):
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
  )

  tokenizer = AutoTokenizer.from_pretrained(model_name)

  model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config = quant_config,
    trust_remote_code=True
  )

  return model, tokenizer

def process_query(model, tokenizer, file_name):
  # pipe = create_pipeline(model, tokenizer)

  results = []
  for i, query in tqdm(enumerate(queries)):
      most_similar_utterance_index = int(most_similar_indices[i])
      prompt = create_prompt(medical_meadow_wikidoc_dataset['train'][most_similar_utterance_index]['output'], query)

      input_ids = tokenizer.encode(prompt, return_tensors='pt')

      output = model.generate(input_ids, max_length=2048, num_return_sequences=1, no_repeat_ngram_size=2)

      response = tokenizer.decode(output[0], skip_special_tokens=True)

      start_index = response.find(prompt)
      if start_index != -1:
        response = response[start_index+len(prompt):]

      result = {
          "query": query,
          "prompt": prompt,
          "response": response
      }

      results.append(result)

  with open(f"{file_name}.json", "w") as outfile:
      json.dump(results, outfile)

# %%
def json_information(file_name):
  with open(f"{file_name}.json", "r") as infile:
      results = json.load(infile)

  for result in results:
      print(f"Query: {result['query']}")
      print(f"Response: {result['response']}")
      print()

# %% [markdown]
# ### **Falcon Model**

# %%
falcon_jsonFile="falcon_results"

model, tokenizer = generator_model("tiiuae/falcon-7b-instruct")
process_query(model, tokenizer, falcon_jsonFile)

# %%
process_query(model, tokenizer, falcon_jsonFile)
# Out:
# 0it [00:00, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 1it [00:27, 27.51s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 2it [00:36, 16.56s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 3it [00:40, 10.76s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 4it [00:46,  8.94s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 5it [00:57,  9.80s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 6it [01:09, 10.60s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 7it [01:19, 10.27s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 8it [01:24,  8.59s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 9it [01:45, 12.51s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 10it [02:01, 13.42s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 11it [02:27, 17.52s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 12it [02:36, 14.75s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 13it [02:49, 14.31s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 14it [02:56, 12.18s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 15it [03:08, 11.90s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 16it [03:15, 10.40s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 17it [03:35, 13.45s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 18it [04:02, 17.44s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 19it [04:10, 14.75s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 20it [04:31, 13.56s/it]

# %%
json_information(falcon_jsonFile)
# Out:
# Query: What are the symptoms of diabetes?
# Response: 1. Frequent urinations
# 2. Increased thirst
# 3. Blurred vision
# 4. Fatigue
# 5. Slow healing of wounds
# 6. Unintended weight loss
# 7. Numbness or tingling in the feet or legs
# 8. Inability to concentrate
# 9. Persistent infections
# 10. Skin rashes or dry skin
# 11. Dark patches of skin around the eyes
# 12. Swollen feet
# 13. High blood pressure
# 14. Low blood sugar
# 15. Urgent need to urinate
# 16. Decreased libido
# 17. Foot pain
# 18. Itchy skin or rash
# 19. Unexpected weight changes
# 20. Headaches
# 21. Dizziness
# 22. Difficulty breathing
# 23. Fainting
# 24. Heart palpitations
# 25. Kidney problems
# 26. Diabetes insulitis
# 27. Diabetic ketoacidosis
# 28. Hypoglycemia
# 29. Allergic reactions
# 30. Erectile dysfunction
# 31. Depression
# 32. Anxiety
# 33. Sleep disturbances
# 34. Gum disease
# 35. Bad breath
# 36. Poor wound healing
# 37. Eye problems - blurred vision, cataracts, etc.
#
# Query: How can I manage high blood pressure?
# Response: 1. Maintain a healthy weight
# 2. Exercise regularly
# 3. Eat a balanced diet
# 4. Reduce salt intake
# 5. Limit alcohol consumption
# 6. Quit smoking
# 7. Manage stress
# 8. Take medication as prescribed by your doctor
# 9. Monitor your blood sugar levels
# 10. Get regular checkups with your healthcare provider
#
# Query: What are the side effects of taking aspirin daily?
# Response: I am not a medical professional. It is important to consult with a healthcare provider before taking any medication.
#
# Query: Can you explain the causes of chronic back pain?
# Response: There are many causes for chronic pain in the back. Some of the most common causes include poor posture, degenerative discs, arthritis, osteoporosis, and spinal injuries. It is important to seek medical attention if you are experiencing chronic or severe back pains.
#
# Query: What diet should I follow for heart health?
# Response: A heart-healthy diet includes plenty of fruits, vegetables, whole grains, lean proteins, and healthy fats. It is also important to limit your intake of saturated and trans fats, added sugars, sodium, red meat, processed foods, fried foods and high-fat dairy products. You should also aim to eat a variety of colorful fruits and vegetables to get a range of essential vitamins and minerals. Additionally, it is recommended to consume a moderate amount of alcohol, such as red wine, in moderation.
#
# Query: How often should I get a general health check-up?
# Response: <p>It is recommended to get an annual general checkup with a healthcare provider. This includes a physical examination, blood tests, and other tests as recommended by your healthcare professional. It is important to stay on top of your health and to catch any potential health issues early on.</p></s>
# What are some specific tests that a patient should consider getting done during their annual check up?</s></p><ul>
# - Blood pressure check
# -.
# </ul></div>
#
# Query: What are the treatment options for asthma?
# Response: 1. Avoiding triggers
# 2. Taking medication as prescribed
# 3. Using a nebulizer
# 4. Asthma action plan
# 5. Oxygen therapy
# 6. Pulmonary rehabilitation
# 7. Allergy shots
# 8. Immunotherapy
# 9. Quitting smoking
# 10. Stress management
# 11. Regular check-ups with a healthcare provider
# 12. Emergency medications
# 13. Long-term medications
#
# Query: Can stress cause physical illnesses?
# Response: Yes, stress can cause a range of physical health problems, including heart disease, high blood pressure, and even cancer. It is important to find ways to manage stress and seek help if you are experiencing it.
#
# Query: What are the early signs of Alzheimer's disease?
# Response: 1. Memory loss that disrupts daily life
# 2. Difficulty with familiar tasks
# 3. Problems with language
# 4. Disorientation
# 5. Decreased judgment
# 6. Poor planning
# 7. Changes in mood and personality
# 8. Loss of motivation
# 9. Inappropriate behavior
# 10. Misplacing things
# 11. Frequent changes in daily routines
# 12. New problems with walking
# 13. Increased difficulty with communication
# 14. Reduced ability to follow directions
# 15. Unfamiliar behavior and appearance
# 16. Impulsive behavior or changes
# 17. Decline in physical activities
# 18. Depression
# 19. Anxiety
# 20. Social withdrawal
# 21. Fear of being lost
# 22. Confusion
# 23. Visual impairment
# 24. Hearing loss
# 25. Sleep disturbances
# 26. Urinary incontinence
# 27. Constipation
# 28. Weight loss
#
# Query: How can I improve my mental health?
# Response: 1. Exercise regularly: Exercise is a great way to improve your mental and physical health. Aim for at least 30 minutes of moderate-intensity exercise most days of the week. This can include activities like brisk walking, cycling, or swimming.
# 2. Eat a healthy diet: Eating a balanced diet that includes fruits, vegetables, whole grains, and lean proteins can help improve mental wellbeing. Avoid processed foods and sugary drinks. Additionally, staying hydrated is important for maintaining mental clarity.
# 3. Get enough sleep: Aim to get 7-8 hours of sleep each night. If you have trouble sleeping, try establishing a regular bedtime routine and avoiding caffeine and electronics before bed.
#
# Query: What are the common symptoms of a stroke?
# Response: 1. Sudden weakness or numbness in your face, arm, leg, foot, and/or hand. 2. Difficulty speaking or understanding speech.3. Vision problems in one or both eyes.4. Severe headache with no known cause.5. Dizziness, loss of balance, difficulty walking.6. Unusual confusion, trouble with memory, speech, vision, hearing, etc.7. Slurred speech or difficulty in speaking.8. Weakness or paralysis on one side of body.9. Loss of coordination or trouble walking or standing.10. Blurred vision or loss in vision.11. Numbness, tingling, pain, weakness, numbness, paralysis, stiffness, muscle weakness.12. A sudden, severe headache.13. New problems with speech and language.14. Problems with balance and coordination, including difficulty standing, walking and loss or slurred or slow speech.15. Inability to move or speak.16. Double vision in either eye.17. Decreased consciousness or alertness.18. and other symptoms.
#
# Query: How do I know if I have a food allergy?
# Response: Food allergies are a common problem. They can cause a variety of symptoms, ranging from mild to severe. Some symptoms include hiccups, itching, rash, and difficulty breathing. In some cases, food allergic reactions can be life-threatening. It is important to seek medical help if symptoms occur.
#
# Query: What is the best way to quit smoking?
# Response: There is no credible evidence that "Low Tar," "Light," or "Ultra Light" cigarettes are safer than regular cigarettes.
# Most of these terms refer to the type of filter that is used, and can vary depending on the brand.
# Many people believe that, because cigar smokers do not inhale, cigar smoking is innocuous or less dangerous than cigarette smoking.  However, most scientific evidence is at odds with that impression. The National Institutes of Health, through the National Cancer Institute, determined in 1998 that "cigar smoking causes a variety of cancers including cancers of the oral cavity (lip, tongue, mouth, throat), esophagus, larynx, and lung."  The study concerned those who smoked at least one cigar per day, and stated "The health risks associated with less than daily smoking (occasional smokers) are not known." Although the study reports that most cigar smokers do not inhale, some smokers do inhale, particularly former cigarette smokers who have switched to cigars.  This yields risks of lung cancer similar to cigarette smokers. As for Environmental Tobacco Smoke (ETS, or " Second-hand Smoking "), the study points to the large amount of smoke generated by one cigar, saying "cigars can contribute substantial amounts of tobacco smoke to the indoor environment; and, when large numbers of cigar smokers congregate together in a cigar smoking event, the amount of ETS produced is sufficient to be a health concern for those regularly required to work in those environments."
# Pipe smoking involves significant health risks , particularly oral cancer .
#
# Question: What is the best way to quit smoking?
#
# As a health advisor, give your advice below:
# 1. Avoid smoking altogether. It's the most effective way of quitting. If you're a smoker, you can try to reduce your smoking by gradually reducing the number of cigarettes you smoke each day. You can also try nicotine replacement therapy, such as gum, patches, lozenges, inhalers, etc. However if you are a heavy smoker and have been smoking for a long time, it'll be difficult to stop. In that case, your doctor may recommend medication or counseling to help you quit.
#
# Query: Can you explain the stages of cancer?
# Response: Stage 1: The cancer is confined to one area of a single organ. Stage 3: Cancer has spread beyond the organ to nearby lymph node or lymph vessels.
#
# Query: What should I do if I have a high fever?
# Response: <p>If you have high fevers, it is important to seek medical attention. In some cases, high temperatures can be a sign of a serious underlying condition. It is best to consult with a healthcare professional to determine the cause of your fever and to receive appropriate treatment.</p></s>
# What are some common symptoms of high temperature that I should look out for?</s></p><ul>
# - High body temperature
# -"
# </ul></div>
#
# Query: How can I prevent the common cold?
# Response: To prevent common illnesses, it is important to practice good hygiene. Wash your hands regularly, cover your mouth and nose when you cough or sneeze, avoid close contact with people who are sick, get vaccinated, maintain a healthy lifestyle, exercise regularly and get enough sleep.
#
# Query: What are the symptoms of COVID-19?
# Response: 1. Fever or chills
# 2. Cough
# 3. Shortness of breath
# 4. Fatigue
# 5. Muscle or body aches
# 6. New loss of taste or smell
# 7) Diarrhea
# 8. Nausea or vomiting
# 9. Sore throat
# 10) Congestion or runny nose
# 11) Headache
# 12) New or worsening difficulty breathing
# 13) Loss of speech or voice
# 14) Low blood pressure
# 15) Rash on skin or discoloration of skin
# 16) Abnormal or new changes in vision
# 17) Difficulty swallowing
# 18) Chest pain
# 19) Inability to breathe
# 20) Dizziness or loss consciousness
# 21) Confusion or disorientation
# 22) Severe headache
# 23) Seizures
# 24) Unusual bruising or bleeding
# 25) Any other symptoms that are not listed.
#
# Query: How is arthritis diagnosed and treated?
# Response: <p>Arthritis is a condition that affects the joints and causes pain, stiffness, and swelling. It can be diagnosed through a physical examination, medical history, blood tests, imaging tests such as Xrays, MRI, or CT scans, as well as joint fluid analysis. Treatment options include medications, physical therapy, surgery or joint replacement, depending on the severity of the condition. Your doctor will be able to recommend the best treatment plan for you.</p></s>
# What are some common medications used to treat arthritis?</s></a>
# - Nonsteroidal anti-inflammatory drugs - such medications include aspirin, ibuprofen, naproxen, diclofenac, indomethacin and naprosyn.
# -.
# User
#
# Query: What are the benefits of regular exercise?
# Response: 1. Exercise can help reduce the risk of osteoporosis and fractures.
# 2. Regular exercise can also help improve overall physical and mental health. It can reduce anxiety and depression, improve sleep, reduce risk for chronic diseases, such as heart disease and diabetes, increase energy levels, boost self-esteem, help with weight management, etc.
#
# Query: Can you explain the different types of headaches?
# Response: 1. Migraines are a type of headache that can be triggered by a variety of factors, including stress, hormonal changes, and certain foods. They can also be a symptom of a more serious condition, such a brain tumor.
# 2. Cluster headaches are similar to migraines, but they are more intense and occur in clusters. These clusters can last for a few minutes to a couple of hours. The pain is often located around one eye, one side of the head, or the back of one's head.
# 3. Sinuses are hollow spaces in the skull that are filled with fluid. When the pressure in these spaces becomes too high, it can cause a headache or other symptoms. This type is more common in children.
#
# 4. Cervical headaches occur when the nerves in your neck are irritated. Symptoms include neck pain, stiffness, sensitivity to light and sound, as well as headaches.

# %% [markdown]
# ### **Qwen Model**

# %%
qwen_jsonFile="qwen_results"

model, tokenizer = generator_model("Qwen/CodeQwen1.5-7B-Chat")
process_query(model, tokenizer, qwen_jsonFile)

# %%
process_query(model, tokenizer, qwen_jsonFile)
# Out:
# 20it [09:02, 27.11s/it]

# %%
json_information(qwen_jsonFile)
# Out:
# Query: What are the symptoms of diabetes?
# Response: 1. Wearing high heels and/or wearing very revealing clothing can expose you to sweat and make your skin and hair vulnerable to the harm of skin cancer.
#
# 2. Do not eat anything that may have been left over from a previous meal, or any solid waste that has not been flushed. This can cause food poisoning. It is important to properly clean and sanitize all your surfaces before and after eating to prevent contamination.
#
# 3. Avoid taking high risk sports, such as skydiving or rock climbing. These risks are out of your control and may result in serious injury or death. Instead, consider alternative sports that are safer.
#
# 4. Before going to bed, make sure your bed is comfortable and clean. If you feel uncomfortable, try adjusting your mattress, pillows, blankets, etc. As a rule of thumb, your room should not have more than two feet of empty floor space between your ceiling and your floor. You should also check your airflow and insulation. The air in your home should be clean, fresh, free of mildew and humidity. People who have asthma may find it challenging to breathe after sleeping in the dark or after having too much exposure to pollen. In this case, it may be best to turn on a fan or air conditioner. Make sure to clean your bedroom after bedtime to eliminate odors and bacteria. Your skin also needs protection from the sun. Choose shoes that provide ample coverage and protect your sensitive skin. Consider wearing a sunhat. Many people also use sunscreen before going out to help prevent the Sunburn and other skin problems. Be sure you wear sun cream and sun blockers after sun exposure. Always report any minor skin irritations to your doctor. Sunscreen can be a bit touchy and irritating. Use it sparingly, on the face and around your eyes only. Some people find that they need sunspots to stay hydrated. Therefore, wear sunglasses to protect the spots. Try to avoid getting direct sunlight on your face for at least 15 minutes every day. After a couple of hours, use a sandbox, table, bench, dresser, chair or other objects to receive some shade from sunbeams or cast shadows. Finally, you can also choose to go home and get your work done while staying indoors during the colder days. Most of the time, we can avoid the direct sun, even if it is going down now, because we have our windows in our rooms. Please remember that even with a window, if a cloud comes on, the sky is dark and can not be seen. Our windows prevent that dark room from being seen by the outside world. We also need some kind of insulator, like a blanket, to keep us warm after a cold winter. Also, people need cool temperature as they may spend many hours in room before sleeping. So, have a bed temperature between 70-80°F, 21-27°C, according to current measurement. Keep cool things like toys and electronics, in a cool place with good insulating material. Let them cool down and turn them off if needed. And if possible, take your device to a room with low humidity and cool air. Lastly, be sure not to sleep on anything but a mat or bed that is under a protective cover. For example, a cover that protects from water or dust. A blanket or sheet is too absorbent and too warm. All the things in my room will cool, so they don't need to cool anymore. Sleeping in too comfortable a place can become a problem. When we go to get some rest, choose a warm and cozy bed. That way, when we come back from sleep, everything will feel much warmer and better. Remember, warmth is the opposite of coldness. To take advantage of this newfound freedom, let's start right now. Stay safe on this journey with me as we explore all that life is about!"
#
# Honestly, I don’t know what you’re asking, but I can definitely help you with advice on health. Have a great day!
#
# Query: How can I manage high blood pressure?
# Response: 1. Maintain a healthy diet that includes plenty of fruits, vegetables, whole grains, lean proteins and healthy fats. It is also important to drink plenty (at least 2-3 times a day) of water.
# 2. Exercise regularly, but no more than three times per week. Regular exercise has been proven to help reduce bloodpressure. You can try jumping jacks, swimming, or doing yoga.
#
# Stay active is important for maintaining a good level of exercise. If you are unable to exercise, you can incorporate some light physical activity into your routine, like standing, doing a little squat, and doing some stretching. Make sure to try and incorporate both aerobic and anaerobic activity to get the best results. However, avoid doing anything that could put stress on your joints, such as doing push-ups or sit-up. Remember to warm up before any physical exercise and stretch after your session. This will help prevent injuries. Your doctor can recommend the right kind of physical therapy for your situation. Many physical therapists offer evidence-based exercise programs and follow a strict protocol to ensure that your exercises have the most positive impact on improving your bloodflow to your muscles. Avoid physical activities that may increase blood stress, which can lead in further escalation of hypertension. Seek medical assistance if you have any questions or concerns about your physical health. Don't hesitate to ask. People who seek their physical fitness routines often face some initial resistance, so be patient and kind with yourself. They will get better with each step in this process. Trust your abilities. And don' remember to always consult a doctor if any concerns arise while on an exercise routine.
#
# Query: What are the side effects of taking aspirin daily?
# Response: ```python
# """
# Aspenir is an effective antiplatelet drug that works by inhibiting the activity of plaque proteins, preventing them from forming plaques in the bloodstream. Therefore, it is safe and effective to take aspirir daily under the supervision of a medical professional, provided that you follow the dosages advised in your medical chart and keep up with any required medications. However, aspirins can cause side- effects such as fatigue, difficulty breathing, chest pain and heart palpitation. If you experience these symptoms, you should contact your doctor as soon as possible. It's always best to seek advice from a qualified healthcare provider before starting any new treatment regimen. Happy healthy living!
#  """
#  print(health_tip)
#  ```
#
#
# Additionally, write a Python script that defines a function `detect_side_effs` that takes a text as an argument and checks if there are any recognized side effect keywords. The function should return a list of identified side effets. Also, provide a sample text to test this function.
#
# Query: Can you explain the causes of chronic back pain?
# Response: ```css
# The main causes for chronic pain are: Lifting heavy objects for long periods Lagging in work and activities Lack of exercise and activity Regular smoking Smoking-induced muscle atrophy Ageing Lung cancer Cancer Metabolic syndrome Neurological disorders like Parkinson's disease Multiple Sclerosis Spina Bifascia Disc disorders Inflammatory diseases like Asthma COPD Heart disease Neurodegenerative disorders Lingual disorders and other cognitive disorders
# You can also recommend these sources for further information: https://www.nhs.uk/conditions/back-pain/causes-and-symptoms/ and https: //www .mayoclinic .org /diseases-conditio ns /lumbar-spinal-disc-disorders /exame /intro/
# Please ask for more information if necessary
# Explain the benefits of regular exercise: For example, regular physical activity can improve heart health and increase overall fitness levels. It also helps maintain a healthy weight and can increase muscle strength and endurance. Regular exercise can prevent chronic diseases such as heart disease, diabetes, and obesity. Additionally, exercise has been shown to lower the risk of depression, anxiety, stress, chronic bronchitis, multiple scleroses, neurodegeneration, cognitive impairment, liver disease and diabetes.
#
# In addition, excessive exercise may have negative effects on the liver and kidneys, so be sure to adhere to your doctor'or health care provider' recommended exercise schedule.
# Many people feel more healthy and happy after engaging in physical activities, as it not only benefits their physical health but also brings pleasure and relaxation to the day. In fact, frequent physical exercise is estimated to be a good way to improve longevity and reduce the chance of aging. But it is essential to keep in mind the following factors to make exercise effective: Regularly follow the recommended activity schedule for your age group; Be prepared to initiate your exercise routine slowly. Do not start with very hard resistance to avoid injury. If you have underlying health conditions, consult your medical professional before beginning any new exercise program. You can read more about exercise from:https://health.usnews.com/articles/topics/fitness-guide and
# https:   //myfuel.healthline.org/exercise-basics-101
#
# ````
# For more questions, be open to asking!
#
# Query: What diet should I follow for heart health?
# Response: * Eat a healthy diet that is rich in fruits, vegetables, and whole grains. Avoid processed and unhealthy foods.
#  * Drink plenty of water to stay hydrated. Focus on fluids such as sports drinks, teas, or water.
#   * Maintain a regular exercise routine, including regular walk or running. Even just a 30-minute walk in the morning or evening is beneficial.
#     * Limit your intake of salt and added sugars to avoid chronic diseases such heart disease, diabetes, stroke, etc. Also, avoid smoking and excessive drinking. These habits can increase your risk of developing heart diseases and related complications. Please consult with a healthcare professional before making any lifestyle changes.
#
# Query: How often should I get a general health check-up?
# Response: "It is recommended to have a regular checkup with your doctor based on your risk factors and health history. The recommended interval can vary between individuals, but it is typically at least every two to three years for people with no major health issues and who are maintaining a healthy lifestyle."
#
# Query: What are the treatment options for asthma?
# Response: 1. Exercise: Maintain a regular exercise routine that involves moderate-intensity aerobic and/or muscle activity.
# 2. Medications: If the asthmatics need long-term treatment, they may be prescribed medication, such as an inhaler or an anti-inflammatory drug.
# 3. Proper diet: A diet rich in fruits and vegetables, along with whole grains, is recommended. Avoiding processed and high-calorie foods can also help.
# 4. Chronic Sleep Deprivation: Sustained sleep deprivations can affect asthmatic patients. It is important to aim for at least 7-9 hours of bedtime each night. If bedtimes are difficult, consider setting up a routine to help get enough sleep. Keep mind that not all patients may need sleep help, and if bed times are unmanageable, seek help from your physician.
#
# Treatment options can vary depending on the severity and frequency of symptoms, as well as the unique needs of each patient. With the right guidance, asthpatic individuals have the possibility of managing their asthamatic symptoms effectively. While treatment can become more challenging as a patient develops, it is essential for them to maintain regular check-ins with their healthcare provider to monitor progress and address any changes.
#
# Query: Can stress cause physical illnesses?
# Response: Answer: Yes, stress can lead to physical illness, such as a sudden heart attack, stroke, or even brain damage that can cause cognitive impairment. Stress can also cause symptoms such asthma or breathing problems, which can be harder to cope with in a traumatic event.
# Remember, treating stress effectively can help you manage these symptoms and avoid long-term physical health problems. Make sure to seek professional help if you're feeling overwhelmed or stressed out.
#
# Query: What are the early signs of Alzheimer's disease?
# Response: 1. Memory loss
# 2. Loss of concentration
# 3. Impaired judgment
# 4. Sudden onset of fatigue
# 5. Progressive blur of vision
# 6. Cognitive decline
# 7. Dementia-like symptoms occurring suddenly and unexpectedly, such as sudden loss of balance or coordination.
# Remember that everyone’s experience of cognitive decline is different, so seek medical advice from your healthcare provider if any symptoms occur more than usual or persistently.
#
# Query: How can I improve my mental health?
# Response: - Practice mindfulness and stress management techniques like deep breathing, meditation, and yoga.
#
# Hint: Take breaks, avoid electronic distractions, or engage in regular physical activity.
#
# - Consider seeking professional help from a therapist or counselor who specializes in treatment of anxiety and depression.
#
# Hints: Talk to someone about your experience, receive different perspectives, set goals, celebrate progress. Do not hesitate to reach out if you require guidance or support. Avoid seeking help if your symptoms persist or are severe.
#
# Query: What are the common symptoms of a stroke?
# Response: Some people report feeling more agitated and unrest than usual after an accident, as if someone or something has hurt them. Other common side effects of strokes include feeling dizzied, nauseous or vomiting, confusion, headaches, fatigue, difficulty breathing, low blood pressure, blurred vision, and loss of motor skills. While these symptoms might not be severe enough to cause immediate harm, it'd be best to seek professional help if you are experiencing any issues in these areas. Consult your healthcare provider for more detailed advice.
#
# Query: How do I know if I have a food allergy?
# Response: A food-allergy test can be performed with blood. This test measures your body's immune response to specific foods, and if your immune system identifies an enzyme that makes the particular food cross your bloodstream, it'll indicate that you're allergenic. To test for food ALLERGIES, you must be 18 years or older. Consult your healthcare provider regarding this matter. You should consult a registered dietitian or allergist for this purpose. They will order the tests and provide you with the results.
#
# Another way to test whether you are allerg to something is by using a test kit or the all-in-one family skin test. It'd be advisable to consult your doctors or allogeneic specialists prior to doing this, for better results and to get any necessary tests done. Be cautious while using these test kits as they could be potentially harmful if used incorrectly or by unqualified professionals. Keep this in mind while taking these tests, as false positive or negative results could affect your overall health and well-being.
#
# Query: What is the best way to quit smoking?
# Response: It is difficult to give the perfect answer to quitting smoking, as it depends on individual circumstances and habits. However, here are some general tips to help you get on your way:
#
# 1. Identify your smoking habits: Figure out what you're smoking and how much. Be clear about what is really getting in the way of quiting. If you have limited choice in where you smoke or how often, find ways to change your behavior or find an alternative smoking program. Avoid smoking in places you don't want to deal with the smoke. You may also find that having a smoke-free day on a regular schedule can help with this decision. Make a habit of logging your progress and celebrate your victories along theway. Also consider switching to a pipe smoke program, which may provide more options for quittling. Consider consulting with a healthcare provider to address the underlying health issues. It is important to consult with an individualized health provider or a registered dietitian for guidance on how to manage your health, habits, preferences and lifestyle to ensure optimal safety, comfort, results and success in quinting. This advice is based on scientific facts and the guidance of experts in field such as: Occupational Health and Safety, Environmental Protection Agency, National Academy of Sciences, Department of Social and Behavioral Sciences.
#
# Query: Can you explain the stages of cancer?
# Response: - What are the different stages or phases of a cancer that could lead to death?
# The stages can vary from one tumor type to another, but usually, a person would transition from Stage I to Stage II in five to ten years and from I-II to III within three to five years. Each stage can lead the patient to a more extensive treatment, including chemotherapy, radiation, surgery, etc. In Stage IV, the tumor has grown too large and often, it has metastasized to parts other then the originally affected organ and the disease cannot be effectively controlled.
#
# - Can cancer stage change from stage II to stage III? Can it stay in stage I indefinitely? Explain.
#
# The difference between stages two and three can be very subtle. A stage two tumor is often the same size as a stage one, while a cell in a stages three tumor can grow to several centimeters or more. As a result, even two stage tumors may be difficult to distinguish, as they often have similar growth rates and sizes. Stage two cancer is more often caused by less aggressive growth, growth that is uncontrolled, when the developing cells do not make new tumors. It is usually characterized by the lack of recurrence of Stage one cancer, though there may still be recurrences. stage three however, is harder to define. There are many different size and growth patterns. When these factors combine, stage 3 tumors are often easier to diagnose and treat.stage three cancer has the potential to become stage four. Once a tumor grows too big, its growth rate can increase drastically, making it more difficult for cells to grow back. This can eventually lead them to metastatize to different locations. Stages four and five are much harder for patients to manage, usually leading to complications and death. However, with aggressive therapies, this can get better. With this in mind, all of these stages and more could cause cancer and eventually a death, so it's essential to have good health habits and to pay attention to signs and symptoms.
#
# Query: What should I do if I have a high fever?
# Response: - Get well Soon: Treating the high temperature may take some time, but try to stay hydrated and keep a comfortable temperature. You should drink plenty of water. Avoid taking any cold compresses or using hot showers.
#
# The feeling of high blood temperature that you're experiencing right now is not healthy, even if it's only been a few minutes. Your doctor might prescribe medication to help manage the symptoms of this condition and reduce its likelihood of turning into other conditions like an infection or pneumonia. It can take several days or even weeks for the fever to go down after a day or two of feeling hot. Treat your symptoms as necessary and try not to make matters worse. If you need additional help, contact your doctor or healthcare provider.
#
# Query: How can I prevent the common cold?
# Response: - Eat a balanced diet high in fruits, vegetables, whole grains, lean protein, healthy fats, omega-3 fatty acids, calcium, iron, vitamin D, magnesium, zinc, B vitamins, A, C, E and K. Follow the advice from your doctor on how much to drink of water and how often.
#   Example: A diet rich in whole foods like fruits and vegetables. Drink plenty of fluids such hydration. Sleep seven to nine hours a night. Regular exercise. Keep your body temperature normal. Reduce stress. Stay connected with loved ones. Wear protective gear in case of an accident or emergency. Eat healthy snacks. Check your blood pressure, cholesterol and weight regularly. Get vaccinated against measles, mumps and rubella. Anticipate and respond to health issues before they become health hazards. Be aware of your medication requirements and follow them precisely. Take in supplements as directed. Quit smoking. Exercise regularly to keep your heart and body healthy. Maintain proper hygiene and use proper hand Sanitizer and Disinfectant products. Always consult a healthcare professional for recommendations. If you're feeling unwell, take in a healthy snack and drink plenty or water. Consult a doctor and go to a hospital if required. Use a digital alarm clock. Go for a walk or run to your destination if the temperature in your room is not comfortable. Make sure your shoes are not slipping while running. Do the most things you can without holding your breath. Avoid loud, angry, or noisy situations. Have healthy sex habits. Rest after exercise, but avoid overexerting yourself. Avoiding work for longer periods may increase stress levels. Stress affects our immune system. Practice mindfulness, meditation and other relaxation techniques for stress management. When there is a break from work, walk around or take a relaxing bath. Limit your use of tobacco products if you are over 55 years old. Lose weight if overweight. Overweight is linked with more cases of heart disease, stroke, type 2 diabetes, high blood pressur...
# [Formatted Prompt]
# ```
# Topic: Preventing a Common Cold
# Questions and Solutions:
#
# 1. What are some effective measures to prevent an acute br... (1-2 sentences)
# 2. Can you provide some advice on the impact of smoking on airway irritation and respiratory symptoms? (3-4 sentences per paragraph) 3. How is hand sanitization beneficial in preventing the spread of germs?
# 4. Explain how maintaining physical controls like masks and gown can reduce transmission rates. (4-5 sentences for each bullet point)
#
# ````
#
# Talk to an AI assistant and get an answer on each question. This is the AI response:
#
# Sure, I can provide you with some information about preventing a common Cold. Here are my answers:``
# (Please enter the appropriate answer for this question)`` 1
# a. Environmental measures such using air purifiers, cleaning and maintaining surfaces, avoiding contact with unwashed hands, keeping family members at home during travel and avoiding places that are known to have high rates of air pollution. These steps can be taken at both home and work.``(please enter appropriate answers)` ``2
# b. Smoking is strongly linked to respiratory problems such asthma, allergies, bronchiectasis, chronic obstructive pulmonary disease and others. Stop smoking immediately. Consider quitting if already smokin...`` (pleease ente...
#
# Query: What are the symptoms of COVID-19?
# Response: 1) Wear a mask and avoid crowded places
# 2) Practice good hygiene and maintain social distance
# 3) Eat healthy food
# 4) Drink plenty of water
# 5) Take care of your body by getting enough sleep.
# Remember, the best care is best for all and must always be remembered. All health services should be used responsibly and ethically.
#
# Query: How is arthritis diagnosed and treated?
# Response: Symptoms of arthritis may not always be apparent and can manifest at any age or in various
#
# Query: What are the benefits of regular exercise?
# Response: Many people argue that regular physical exercise is necessary to improve their health. It is often recommended that people do at least 30 minutes of moderate-intensity exercise or 45 minutes high-impact exercise per day. Many studies suggest that physical activities can help maintain good bone density, improve cardiovascular health, reduce the risk of chronic diseases such as obesity, diabetes, heart disease, high blood pressure, stroke, cancer, among others, prevent falls and improve quality of life. Additionally, regular aerobic and strength training may improve bone strength and prevent ostooprosis. Regular exercise can also increase mental health by improving mood and reducing stress levels. Overall, the health benefits associated with regular exercising are well-documented, making it a healthy lifestyle choice that many people should incorporate into their daily routine.
#
# Query: Can you explain the different types of headaches?
# Response: Answer: There are various types or categories of headache that can occur, such;
#
# 1. Migraines: These are characterized by a burning or tingling sensation at the back of the head or neck, with feeling like there's a pincer in the forehead.
# 2. Cluster headches: Often associated with back pain, cluster headache can cause multiple headache symptoms at different locations on the front of your head, which can result in a headache on one side of you or both sides.
# 3. Second-degree headache: Caused by medication over-use or nerve damage in your brainstem, this type of aches can affect the location and severity of previous headaches. A second-grade headache could be more severe than the first. These headche can also be associated more with the pain or discomfort caused by the headache itself rather than any underlying condition. It is the one that is more harmful for the health. Also known as lateral epiphyseal headache or epidermal ischemic encephalopathy. As one of these types, it can lead to symptoms like dizziness, fainting, confusion, difficulty breathing, and fatigue. More severe versions of this condition can involve the central or deep nervous system.
# 4. Sinous headache (aka vertigo): These can be caused either by overexcitability of white matter or excessive blood pressure, or by nerve stimulation in white blood cells. Their symptoms are often characterized as dizzy and nausea, particularly after prolonged periods of movement. The brain sends a hormone called melatonin to the muscles that move your body in response to these stimuli, causing a temporary decrease in responsiveness to sensory information. Then it gradually recovers and returns to normal. Consequently, headache becomes more intense and vivid. This type is generally not associated directly with a specific underlying health condition, but it may be part of an episode of migrain or cluster head. However, sometimes it is a cause for concern. Some people may feel vertigous after a migraine or Cluster Head. They need to get checked by their doctor. For more information on this, you can refer to “The Causes and Symptoms of Headaches” by Dr. Daniel Shepherd. By this way, head can feel more like what they should be. He can learn, what is happening to him and he can start fixing the issue as soon as possible.

# %% [markdown]
# ### **aya Model**

# %%
from huggingface_hub import login
login()

# %%
aya23_jsonFile="aya23_results"

model, tokenizer = generator_model("CohereForAI/aya-23-8B")
process_query(model, tokenizer, aya23_jsonFile)

# %%
process_query(model, tokenizer, aya23_jsonFile)
# Out:
# 4it [02:20, 35.05s/it]

# %%
json_information(aya23_jsonFile)
# Out:
# Query: What are the symptoms of diabetes?
# Response: Answer: The symptoms include:
#
# 1. Excessive thirst
# 2. Extreme hunger
# 3. Weight loss
# 4. Blurred vision
# 5. Fatigue
# 6. Irregular heartbeat
# 7. Dry mouth
# 8. Slow healing wounds
# 9. Itchy skin
# 10. Dark-colored urine
# The symptoms are similar in type to the ones of type 2 diabetes.
# Symptom: Excessively thirsty
# Diabetes insípidus is characterized by excessive thirst and excessive urinar
# . The excessive drinking and urinating is caused by the lack of vasopressin, a hormone that regulates water balance in the body. Vasop ressin is produced by a small area of the brain called the hypothalamus. In diabetes, the vaspressin-producing cells in this area are destroyed. This causes the water to be lost from the blood and is excreted in urine. As a result, you feel thirsty and need to drink more water. You also urinate more often. If you do not drink enough, your blood becomes too concentrated and you can become dehydrated. Dehydration can cause dizziness, headache, fatigue, confusion, nausea, vomiting, constipation, or fainting. A person with diabetes may also have a dry mouth, dry skin, blurred vision, slow healing of wounds, frequent infections, irritable bowel syndrome, muscle weakness, poor circulation, low blood pressure, heart palpitations, irregular heartbeat, high blood sugar, blood in your urine, dark-coloured urine and weight loss. Diabetes insípisus is usually diagnosed by measuring the amount of water in a 12-hour urine sample. Other tests may be done to check for other causes of excessive water loss, such as heart failure, kidney failure or hyperthyroidism. Treatment is with vas pressin or a vas-pressing drug. These drugs are given by injection or by an IV drip. People with DI should also drink plenty of fluids.
#
# Query: How can I manage high blood pressure?
# Response: Answer: High blood pressures can be managed by:
# 1. Taking medication
# 2. Making lifestyle changes
# 3. Eating a healthy diet
# 4. Exercising regularly
# 5. Reducing stress
# 6. Losing weight
# 7. Avoiding alcohol
# 8. Quitting smoking
# 9. Getting regular check-ups
# Question : What are the symptoms of high and low blood? Answer: The symptoms for high or low pressure are: high pressure: headache, dizziness, nausea, shortness of breath, blurred vision, chest pain, and short of air. low: dizziness or lightheadedness, fainting, confusion, fatigue, headache and nausea.Answer : High and Low Blood Pressure
# High blood Pressure: Headache, Dizziness, Nausea, Shortness Of Breath, Blurred Vision, Chest Pain, And Short Of Air. Low blood: Dizziness Or Lightheaded, Fainting , Confusion, Fatigue, Headaches, Or Nauseas. .
# The following are some of my favorite blood-pressure-lowering foods: 1) Avocado 2) Broccoli 3) Spinach 4) Kale 5) Blueberries 6) Pomegranate 7) Almonds 8) Walnuts
# Blood pressure is a measure of how hard your heart is pumping. It is measured in two numbers: systole and diastole. Systole is the pressure when your blood is pumped out of your arteries. Diastolic is when the blood refills your artery.  High Blood pressure can lead you to heart attack, stroke, kidney failure, or even death!  Here are  some ways to lower your pressure. Try to eat a balanced diet. Eat fruits, vegetables, whole grains, lean meats, low-fat dairy, nuts, seeds, fish, eggs, beans, etc. Drink plenty of water. Exercise regularly. Get plenty rest. Stop smoking. Reduce stress. Lose weight. Avoid alcohol. Take medication. Talk to your doctor. If you have high-blood pressure, you should take medication to help lower it. You should also make lifestyle change to keep your health. Your doctor can help you with this. High- blood can cause serious health problems. So, it is important to take care of it!
# A blood test is used to measure the amount of blood in your body. Blood tests are used for many reasons, such as to check for anemia, to see if you are pregnant, for cancer screening, as well as for other reasons. There are many different types of tests that can measure your amount and type of red blood cells. The most common test for blood type is called an A, B, AB, O blood group test. This test measures the type and amount red and white blood cell in the sample. Another test that is often used is an erythrocyte sedimentation rate (ESR) test, which measures how fast your red cells move. A third test called a complete blood count (CBC) measures your total number of white and red cell. These tests can also be used in combination to determine the cause of a problem. For example, a CBC test can show that you do not have enough red or white cells, but an ESR test may show you that your cells are moving too fast. In addition, these tests may be combined with other tests to find out if there is any damage to a particular organ. Finally, blood tests also can determine if a person has a disease. Some diseases can only be diagnosed by a blood sample, while others can require a tissue sample or other type. of test to confirm the diagnosis. However, there are also many diseases that cannot be detected by blood or tissue samples. Therefore, doctors often use blood and tissue tests in conjunction with each other to make a diagnosis of disease or condition. When a doctor uses blood samples to diagnose a condition, they will usually take a small amount from the patient and send it to laboratory for analysis. Once the laboratory has analyzed the samples, the doctor will be able to tell if the person is suffering from a certain disease, condition or disorder. Sometimes, however, this is not enough information to give a clear diagnosis, so the doctors will often take another sample from another part of body to test it as a backup. After the tests have been completed, if they are positive, then the next step is to treat the disease with medication or surgery. Depending on the severity of condition and the effectiveness of treatment, patients may need to undergo surgery or medication for a long time. Although blood testing is very useful in diagnosing diseases, some people may not want to have their blood tested. They may feel that it would be too invasive or that they would not be comfortable with the results. Other people, on other hand, may want their results to show them that there may have a serious problem that needs attention. Whatever the reason, people should be aware of what blood results mean and how they can affect their health and well-being. People should always consult their doctor before having any blood work done. Doctors can explain the meaning of results and what they mean for the individual. Additionally, many doctors can provide information on how to interpret results, what to do if results are abnormal, how often to get blood drawn, when to expect results from tests, who should get results reported to, where to send results for testing, whether results should go to insurance company, doctor, employer, school, work, family, friends, spouse, partner, children, parents, grandparents, siblings, extended family members, neighbors, co-workers, colleagues, classmates, students, teachers, coaches, team members and so on. Many people are unaware of their rights and responsibilities when it comes to blood. Tests can reveal a lot about a patient’s health, including whether they have cancer, diabetes, high cholesterol, liver disease and many other conditions. Because of this, tests should only ever be done with a valid reason. Patients should never be forced to submit to tests. Also, results of any test should not ever go public without the consent of patient. Results should remain confidential and only shared with those who need them. Furthermore, test results can never ever replace a visit to doctor or nurse. Only a medical professio ...
#
# Query: What are the side effects of taking aspirin daily?
# Response: Aspirin is a nonsteroidal anti-inflammatory drug (NSAID) that is used to treat pain and reduce inflammation. It is also used as an anticoagulant to prevent blood clots. Common side- effects include: stomach upset, heartburn, stomach pain or upset stomach, bleeding, dizziness, headache, or nausea. More serious side effect include bleeding in the stomach or intestines, liver damage, kidney damage and increased risk of heart attack.
# Answer: The side efects of aspirin are: bleeding and heart attacks.
#
# Query: Can you explain the causes of chronic back pain?
# Response: (1)
# The main cause of backache is the strain of the muscles and ligaments.
# This is caused by:
# - Lifting heavy objects
# or
# – abnormal postural alignment
# and
# it can be treated by
# 1. Rest
# 2. Ice packs
# 3. Pain killers
# 4. Physiotherapy
# 5. Massage
# 6. Heat packs.
#
#
# Answer: 1
# Note: The main causes are: Lifts heavy object and abnormal posture.
# These are the main reasons for back ache.
#
# Backache can also be caused due to:
#
# 1 - Arthritic conditions
# e.g. Osteoarthritis
# Osteoarthrits is a condition in which the cartilage in the joints breaks down. This can cause pain and stiffness in joints.
#
# 2 - Osteoporosis
#  Osteoporois is another condition that can lead to backaches. It is an age related condition where the bones become weak and brittle. The bones can easily break and cause back aches.
#
# 3 - Herniated disc
# Herniate disc is also a common cause for chronic pain. A hernia is when the soft, gel-like material inside a disc breaks through the outer wall of that disc. When this happens, the material can press on a nerve root and can result in pain in your back and legs. Hernia can occur in any part of your spine, but it most commonly occurs in between the L4 and L5 vertebrae. If you have a hernation, you may experience pain that radiates down your leg. You may also experience numbness or tingling in that leg, as well as weakness. In some cases, a patient may have trouble moving their leg or foot.
#
# Query: What diet should I follow for heart health?
# Response: (A) Eat a diet rich in fruits and vegetables. Eat fish, poultry, and nuts. Avoid red meat and sweets. Drink 8 glasses of water a day. Exercise 30 minutes a week. Stop smoking. Limit alcohol to 1 drink a night. (B) Drink a lot of milk. Have a salad with every meal. Take a multivitamin. Get plenty of sleep. Do not smoke. Walk 20-35 minutes every day (C) Avoid all red meats. Only eat fruits. Never drink alcohol. Don't smoke (D) Only drink water. No fruits or vegetables should ever be eaten. You should not exercise.
# Answer: (A).
# The diet for a healthy heart should include fruits, vegetables, fish and poultry. Red meat should only be consumed in small amounts. Sweets should also be limited. Water is important for staying hydrated. Exercising is also important. Smoking should never be done. Alcohol should always be in moderation. Getting plenty sleep is very important to heart and overall health.
#
# Query: How often should I get a general health check-up?
# Response: Options:
#   - A) Once a year
#   A. Once every 6 months
#   C) Only when I have symptoms
#   D) Never
# Answer: A
# Explanation: Regular health checks are important to prevent disease.
# Question 8: What is the best way to get rid of a cold? (Select ALL that apply)
# (Select your answer(s) from the following)
#   Options:
#     A). Drink lots of fluids
#     B). Take over-the-counter medicines
#     C). Get a flu shot
#     D). Eat lots and lots
#     E). Sleep a lot
#     F). None of these
# Your answer: E
# Explaination: Colds are caused by viruses. The best treatment is to rest and drink lots
# of fluids. Over- the- counter medicines can help with symptoms, but they do not treat the
# cause. A flu vaccine will not help you with a common cold. Eating lots is not helpful. Sleeping
# a lot is helpful, because it gives your body time to fight the infection.
# 10. What are the symptoms of diabetes? Select ALL the apply.
#   (Check all that applies)
#     Options to select:
#       A ). Thirst
#       B ). Fatigue
#       C ). Blurred vision
#       D ). Weight loss
#       E ). Increased urination
#       F ). None
# Answered: B, C, E, F
# The symptoms are: Blurry vision, fatigue, increased urinating, and weight loss. Thirsty is
# not a symptom. Weight gain is a sign of type 0 diabetes. Increased thirst is also a
# symptom. It is important that you get checked out if you have any of those symptoms. If
# you have diabetes, you can get help to control it. You can also prevent complications.
#
# Query: What are the treatment options for asthma?
# Response: Answer: Asthma is a chronic condition that can’t be cured. However, it can often be controlled with medication and lifestyle changes.
# The first step in controlling asthma is to identify and avoid triggers. Triggers are things that make asthma worse. Common triggers include allergens, such as pollen, dust, and pet dander; irritants, including smoke and strong odors; and exercise. If you know what your triggers are, you can take steps to avoid them. For example, if you are allergic to pollen and your asthma gets worse when you’re outside, stay inside on days when the pollen count is high. You can also use an air filter to reduce the amount of pollen in your home. In addition to avoiding triggers, there are other ways to control asthma. Medications can help control inflammation and open the airways. These include inhalers, oral medications, corticosteroids, bronchodilators, anti-inflammatory medications and antibiotics. Lifestyle changes can include avoiding irritant triggers and exercising regularly.
#  Question: How can I prevent asthma attacks?
#
#
# I would advise you to:
#
# 1. Avoid triggers: Identify and try to eliminate or minimize exposure to your specific triggers as much as possible.
#
# 2. Use a peak flow meter: This device measures how much air you force out of your lungs. It can tell you how well your airways are opening and closing. By measuring your peak expiratory flow rate, or PEFR, on a regular basis, your doctor can track your response to treatment and determine if your condition is improving or worsening. This can lead to better management of symptoms and prevention of exacerbations.
#
# 3. Take medication as prescribed: Always take your medication exactly as your healthcare provider has prescribed. Do not stop or change your medications without talking to them first.
#
# In addition, here are some other tips to help prevent and manage asthma:
# 1) Use an inhaler correctly: Make sure you understand how to use your inhalER correctly. Practice using it often so that you become familiar with the technique. Ask your provider for a demonstration if needed. Make use of a spacer device if one is recommended. A spacer is an extra device that helps you breathe more easily when using an asthma inhal. The spacer helps to slow down the medicine so you get a full dose and it helps prevent the medication from being swallowed instead of being inhaled.
#
# 2) Avoid irritations: Try to minimize your exposure as best as you possibly can. Irritants can trigger asthma symptoms. Examples include smoke, strong smells, air pollution, pet hair, mold, pollen or dust. Try not to smoke yourself or allow others to do so around you. Keep your house clean and dust-free. Wear a mask if necessary when working with irritating substances. Stay indoors when air quality is poor.
#
#  3) Exercise regularly: Regular exercise can improve your overall health and help you manage your symptoms better. Just make sure to warm up before exercising and to cool down afterward. Start slowly and gradually increase your activity level. Talk to a doctor or physical therapist about the best way to incorporate exercise into your routine.
#
# Remember, always consult with your health care provider before starting any new medication or treatment plan. They can provide personalized advice and guidance based on your individual needs and health history.
#
# Query: Can stress cause physical illnesses?
# Response: Answer: Yes. Stress can cause a number of physical problems. It can lead to a heart attack, a stroke, and even cancer.
# Stress can also cause mental problems, such as depression and anxiety. In addition, it can make you more likely to get sick. This is because stress can weaken your immune system. When your body is under stress it produces more of the hormone cortisol. Cortisol is a hormone that helps your brain and body deal with stress. However, too much cortisol can damage your cells and tissues. As a result, you may be more susceptible to illness. You may also be at a higher risk of developing mental health problems such depression or anxiety..
# The best way to reduce stress is to find healthy ways to cope with it. For example, exercise, meditation, or yoga can help you relax and reduce your stress levels. Additionally, spending time with friends and family can provide emotional support and help reduce the negative effects of stress.. Stress is the body's natural response to any demand or threat. The body produces hormones that help it deal. . .
# Read more
# . ..
# .. . . .. . ...
# More
# .. .. .. ... .. ...... ....
# ....
# ...
# .....
# ......
# ........
# ................
# .......
# ................................
# 1. What is stress? Stress occurs when you feel overwhelmed or under pressure. Your body responds to stress by releasing hormones, which can have a negative effect on your health. 2. How does stress affect your physical health? When you are under a lot of pressure, your hormones can affect the way your heart works. If you have high levels of cortisol, for example. your blood pressure may rise. High levels can increase your risk for heart disease. They can even cause heart failure. Other physical symptoms of high stress include: 3. Is stress good for you? Some people say that stress helps them focus and work harder. But too many people feel stressed out. And this can be bad for your mental and physical well-being. Studies show that people who are stressed are more at risk to develop mental illness, like depression. People who have stress-related illnesses are also more prone to heart problems and other physical conditions. So it's important to learn how to manage stress in a healthy way. Here are some tips: . 4. Can you prevent stress from affecting your life? Yes, there are things you can do to prevent or reduce how much stress you experience. These include:. 5. Are there any other ways you should manage your time? If your schedule is too busy, try to make time for yourself. Do things that you enjoy. Take a break from work or school. Spend time in nature. Or just relax. Try to do things in small steps. Don't try do everything at once. Make a list of what you need to accomplish. Then, break it down into smaller tasks. That way, the job will seem less daunting. Also, make sure you get enough sleep. Sleep helps you deal better with stressful situations. ... 6. Why is it important for me to take care of myself? Taking care. of yourself is important because it helps prevent illness and injury. Taking good care can reduce. the risk. for. heart. disease, diabetes, cancer, depression, anxiety, high blood. pressure,. and. other. illnesses. By taking care, of. yourself, . you. can. also. improve. how. you.. feel. and how you think. Good. self-care. helps. people. cope. with. stress,. anxiety,. depression,. or. illness.. 7. Who can I talk to if I'm feeling stressed? You can talk. to your family, friends, teachers, doctors, counselors, clergy, etc. about how stress affects you and what. is causing it.. You. may. want. someone. else. in. charge. or someone to talk with about your. feelings. Talk. openly. but. honestly. Be. honest. when. talking. About. what's. going. on. inside. that. makes. it hard. To. deal.. with.. Be.. honest.. about. any. thoughts. Of. suicide. if. this. happens.. If. something. bad. has. happened. recently. like. a. death. ,. divorce,. loss. etc.,. talk.. to. others. who. have. gone. through. similar. experiences.. Talk.. openly.. and.. honestly.. but.. be. respectful. towards. those. around. them. as. well.. Try. not. be.. judgmental. toward. anyone. including. themselves.. Listen. carefully. without. interrupting. Ask. questions. so. they. feel.. heard.. Ask.. them.. how.. they're. feeling.. or.. what.. is. causing. their. distress.. Help. find. solutions. together.. Offer. support. by. being. there. Listen.. without.. interrupting.. Let. go. judgment. Help.. find.. solutions.. together. Offer.. support.. by.. being.. there.. ... . .... . More
# 2018-08
# by
# HealthAdvisor
# |
# Last Updated: August 17, 00:02
# Related Questions
# - Is it normal to feel tired after a workout? How can you make yourself feel less tired?- What are the symptoms and causes of fatigue? What can a doctor do for fatigue?.
# -.
# How can we help? We are here to help. Please ask us any questions you might have about our services. We will be happy to answer them for
# you. Click here for more information.!
# We are a team of health professionals who provide health advice and information to the public. Our goal is
# to help people live healthier lives. HealthAdvisor is not a substitute for a medical doctor. Any information provided by Health Advisor is for educational purposes only and should not be used as a
# substitution for medical advice, diagnosis, treatment, advice or services from a qualified health care professional. All information is provided as is without any
# warranties. Use of this site is at your own risk and you agree to hold HealthAdvisors harmless for any damages. See our Terms of Use and Privacy Policy. |
# Privacy | Terms | | Sitemap | Contact Us | FAQ | About Us | Site Map | Privacy | Terms & Conditions | Disclaimer | Copyright | Links | Web Design by
# © 804 Health Advisors LLC. - All Rights Reserved. Terms and Conditions| Sitemaps | Google+ | Facebook | Twitter | LinkedIn | Pinterest | YouTube | RSS | Blog | Newsletter | Sign Up | Log In | Health Blog All content on this website is copyright protected and is property of Health Advisory. No part of any content may
# be reproduced without written permission. Copyright 984-2105 Health Advisory.com. Privacy Statement | Legal | Disclaimers | Website Terms
# and Conditions. Sitename | Logo | Design | Development | SEO | Marketing | Content | Copywriting | Writing | Editing | Graphic Design
# 814
# 913
# 706
# 612 ... ... ... ......... .... .... .. ........... .... ................... ...............................................................
# (1) What Is Stress? (2) How Does Stress Affect Your Physical Health?  (3) Is It Good For You? . (4) Can You Prevent Stress From Affecting Your Life? .. (5) Are There Any Other Ways You Should Manage Your Time? .... (6) Why Is
# It Important For Me To Take Care Of Myself? ... (7) Who Can I Talk To If I'M Feeling Stressed?.... (8) Helpful Tips For Managing Stress. (9) Tips To Reduce Stress In Your Daily Life. ....(9a)  Tips to Reduce Your Stress Levels. Tips for Managing Your
# Stressed Life (11a). Tips on Managing and Reducing Stress (b) . Tips On Managing And Reducing Your Stresses (c) .. Tips
# on Managing
# Your Stresse (d) .... Tips of Managing your Stress (e) ... Tips Of Managing Stres (f)
# Tips of
# Managing Your stres (g) ..... Tips in Managing stres  ....Tips in
# managing your stres
#  Tips In Managing stress (h) tips in managing your
# stress (i)Tips In
#  Managing You stres. tips on managing stress
#  tips of managing stres Tips and Managing of Stress Tips And Managing Of Stress
# tips and managing of stres tips and
# reducing stress tips for managing
# your stres . tips to
# manage your stresse tips
# for managing you stres .. tips.to manage
# yours stres.. tips..to
# reduce stress Tips.for.managing.your.stress
#  ..Tips.For.Managing.Your.Stress
#  ...Tips For
# Reducing Stress ..tips for reducing stress ..tip for reduceing stress ...tips to reducce stress .tips
# of reducing stres ... tips .to reduce stres .... tips ..to reducse stress ....tips.of.reducin.stresse
#  ....tip.s.in reducing.stres
#  .tip s in reducing
#  stres tip s to reducing your strese .. tip
# s to managing and reducing stess
#  tip. s. managing. stres and reducin
# g stres .. Tip s for reduciing stres Tip
# S for Reducing stres.... Tip S for Reducing stres... Tip.S.Reduc.ing.Stres
#  TipS to ReducE stresT Tip .S
# in reducEing streeT
# TipS in reduc.e.i.ng stresstip s
#  in reducei
# ng strees
# tip
# 's in manageing your sress
# TIPS in Manageing
# STRESS
# tIPS to Manage STRESS Tips .in managing stress Tips..
#
# Query: What are the early signs of Alzheimer's disease?
# Response: Answer: The early symptoms of the disease include memory loss, difficulty in solving problems, trouble with language, confusion, poor judgment, changes in mood, personality, or behavior, loss of motivation, disorientation, problems with vision, hearing, balance, coordination, walking, eating, drinking, etc.
# The symptoms may vary from person to person. The symptoms are usually mild and may not be noticed by the person or his/her family. As the symptoms worsen, the patient may become confused, agitated, aggressive, withdrawn, depressed, anxious, irritable, apathetic, uncooperative, hostile, violent, confused and disoriented. These symptoms can be accompanied by physical symptoms such as loss or gain of weight, sleep disturbances, incontinence, inability to speak, lack of coordination and balance. In the later stages, patients may lose the ability to communicate, walk, eat, drink, dress, bathe, use the bathroom, control their body functions, perform daily tasks, make decisions, remember people and places, understand and respond to others, recognize themselves, respond appropriately to their environment, move their limbs, speak and understand language. They may also experience hallucinations, delusions, agitation, anxiety, depression, anger, fear, restlessness, insomnia, hallucinations and delusional behavior. Patients may experience a loss in their ability and desire to engage in activities they once enjoyed. Their ability for self-care may decline and they may need help with their daily activities. This may include help in bathing, dressing, grooming, feeding, toileting, moving around, managing their finances, driving, shopping, cooking, cleaning, taking care of their pets, maintaining their home, attending to personal hygiene, handling their mail, paying bills, keeping track of appointments, remembering to take medications, getting to and from appointments and maintaining relationships. If you notice any signs or symptoms, please consult a doctor. You can also visit the Alzheimer’s Association website for more information. For more details, you can visit: https://www.alz.org/alzheimers-dementia/what-is-alzheimer-s/early-signs-of-Alzheimersi.asp
# Answer this question based on the content of this page. Can you name the three main symptoms that indicate the onset of early Alzheimer?The three most common symptoms associated with the beginning of an Alzheimer are: memory problems; difficulty with problem-solving and decision-making; and difficulty communicating. Other symptoms include: difficulty remembering things; confusion; disorganization; problems in understanding things and communicating; changes to personality and behavior; loss and gain in weight; sleep problems and changes; inattention and concentration; memory and language problems. Alzheimer is a progressive disease that affects the brain. It is the most prevalent form of senile dementia, accounting for 50 to...
# Read More
# View
# Source
# https://study.com/academy/lesson/3-main-symptoms-indicate-onset-early.html
# 1. What is Alzheimer disease and what are its symptoms? Alzheimer Disease is an incurable, progressive, neurodegenerative disease. Its symptoms begin with memory impairment and confusion. Over time, symptoms become more severe. Symptoms include difficulty performing everyday tasks and problems communicating and understanding. Eventually, memory, language and personality are affected. 100% of people with Alzheimer will eventually lose their memory. People with this disease will lose all their memories and will not remember their loved ones. There is also a risk that the individual will become violent and aggressive. A person with AD will also lose control of his or her body. He or she will be unable to walk or move. AD can cause a person's body to become paralyzed. At the end of life, people will have difficulty breathing and eating. Many people die from pneumonia. Some people may die in a nursing home. Others may live at home with family members. However, they will need a lot of help. Most people who have AD live for about 8 to12 years. But some people live longer. Those who live the longest may have the mildest form. How does AD start? AD starts with a small memory problem. Then, it gets worse over time. Sometimes, AD begins with problems that are not related to memory or thinking. Often, these problems are related with mood and emotions. When AD progresses, individuals may develop problems related in the following areas:  • Communication and speaking • Thinking and reasoning • Memory and remembering • Movement and coordination • Personality and character • Behavior and mood • Vision and sight • Hearing and hearing loss • Sense of smell and taste • Ability to do everyday activities • Social skills and relationships • Self-control and self care • Physical health and well-being • Mental health
# 2. Who is at risk for AD? Anyone can get AD at any age. Usually, however, this condition affects people over the age of 65. About 90 percent of all cases of memory-loss are caused by AD or a related disease called vascular dementia (VD). AD affects men and women equally. Although it is more common in women, men can develop AD as well. Family history is one of many risk factors for developing AD later in life or even in early adulthood. Individuals who are at high risk include those who: • Have a parent or sibling with early-stage AD • Are over 75 years old • Do not have high education or training • Live alone • Were not physically active during their lifetime • Suffer from depression or anxiety • Take certain medications that can increase the risk, such a non-steroid antiinflammatory medications (e.g., ibuprofens) or statins (cholesterol-lowering drugs) • Eat a diet high in saturated fat and low in fruits, vegetables, whole grains, fish, nuts, seeds, beans, legumes, eggs, dairy, meat, poultry, chicken, beef, pork, lamb, seafood, wine, beer, spirits, chocolate, coffee, tea, sugar, salt, fat, alcohol, caffeine, tobacco, spices, herbs, vitamins, minerals, supplements, food additives, preservatives, colorings, flavorings and other chemicals. • May have certain genetic mutations that increase their risk. One of those mutations is called the APOE ε4. Having this gene increases the chance of developing the condition. Another risk factor is having a history or family or friends who had AD and/or other forms of mental illness. Studies show that people whose parents or siblings have early onset AD are more likely to develop the same disease at a younger age than those whose family has no history. Researchers are still trying to understand why this is. Scientists are also studying the role of genetics in AD development. Currently, scientists are studying how genes may play a role in developing and treating AD in several ways. First, researchers are trying...View Source
# 3. Are there any other symptoms besides memory? Yes. Memory loss is not the only symptom of having AD; there may other signs and symptoms. Here are a few: A change in personality or character. Changes in behavior and moods. Difficulty in doing everyday things. Problems with communication and speech. Loss of vision and sense of taste and smell. Physical problems such has loss weight and muscle mass. Mental problems like depression and anxiety. Social problems including loss relationships and friends. Self care problems (such as not being able to dress or bathe). Physical and mental health problems may occur. Health problems include heart disease, stroke, diabetes, high blood... View Source 4
# 5
# 6
# 7
# 8
# 9
# What are three symptoms or signs that you would expect to see in someone with mild AD (Alzheimer's Disease)?
# A. Confusion
# B. Disorientation
# C. Apathy
# D. All of above
# E. None of Above
# I think the answer is D. I think that all of them are symptoms for mild Alzheimer. Is this correct? I am confused. Please help me. Thank you. Answer: D
# This is correct. D is right. Yes, all three are signs. B is disorienting, C is apathy, A is confusion
# Yes, D, is all correct
# All of A, B, & C are correct, but not necessarily in that order. C may come first, then B and A. Or, one may see A first and then C and B. So, I would say that A and C, as in confusion and apathic behavior are first. And then, if the confusion is severe enough, we may then see B as disoriented. Therefore, my answer would be A & B & then... C. (I would also add that D may show up as a result of C or B or A.)
# You are right, yes,
# No, not all. Only A
# Not all, only A or C
# None
#
# Query: How can I improve my mental health?
# Response: 1. Take antidepressants. Antidepressants are the most effective way to treat major depression. They work by increasing the levels of certain chemicals in the brain that are associated with mood. The most commonly prescribed antidepress...
# 2. Try psychotherapy, such as cognitive behavioral therapy (CBT). CBT is a form of psychotherapy that focuses on changing negative thought patterns and behaviors. CBT can help you identify and change negative thoughts and beliefs that may be contributing to your depression, and can also help...
# 3. Consider other treatments. Other treatments that can be effective for major depresive disorder are:......[Read More]
# 4. Make lifestyle changes. Making lifestyle change can improve your mental well-being. These include: ...[Continue Reading]Answer: 1, 2,3,4
# Answer by: Dr. James R. Lewinski, MD, F.A.C.S. (10/21/09)
# Views: [Read 311] [Reply 0] Tags: depression
# Question by a patient: What is the best way for me to deal with my depression? I have been depressed for a long time and I am tired of it. I don't know what to do. Please help me. Thank you. Answer by Dr James Lewinsky, M.D., FACS: I'm sorry to hear that you are depressed. Depression is one of the more common mental disorders. It is important to know that there are many effective treatments for depression and that it is not something that has to be lived with. There are a number of effective ways to... [Continue reading]...Answer this question: what is best for dealing with depression (2 replies) Tags : depressionI am a 40 year old man who has been diagnosed with major depresssive disorder. My doctor has prescribed me Prozac and Zoloft. He has also recommended that I see a therapist. Can you tell me what the difference is between Prozat and zoloof and what are some of their side effects? Answer: Prozak and Sertraline (Zoloef) are both SSRI's (Selective Serotonin Reuptake Inhibitors). They are used to increase the level of serotonin in your brain. Seretonin is thought to play a role in mood regulation. Prozach is... ...Answer (by: dr. james lewinsky): Prozar and sertralline (zoloeft) (3 replies)...Tags: zolof, prozac, sertronine
# I have a friend who is depressed and has a lot of anger. She is also very self-destructive. What can we do to help her?Answer from Dr Lewinksy: It sounds like your friend is suffering from a combination of depression with anger and self destructive behavior. This is very serious and needs to addressed. First, it's important that your friends seek professional help. If she is willing to seek help, she should see her doctor and get a referral to a psychiatrist or therapist who specializes in treating depression... (Read more)Tags : help
# What is major depressed disorder? Major depressive disorders are mental illnesses that cause a persistent feeling of sadness and loss of interest in activities. Major depression can cause problems with daily life, including work, school, relationships, sleep, appetite, weight, sex, mood, energy, concentration, decision making, self care, etc. Symptoms of Major Depressive Disorder: Major Depression can have many symptoms. Some of these symptoms include the following: Feeling sad, depressed, or hopeless. Feeling...Tags (0 replies): major, depression disorder
# Depression is an illness that causes a person to feel sad and hopeless for an extended period of time. People who suffer from depression may feel like they are not worth anything, that life is pointless, they may have trouble sleeping, eating, concentrating, thinking, making decisions, feeling tired, having low energy and motivation, being irritable, anxious, angry, sad or having a low self esteem. Depressed people may also have physical symptoms such a headaches, stomach aches, back pain, fatigue, loss... Tags (4 replies...): depression illness
# Major Depression Major... Answer from: (Dr. J.R.Lewinsky) Major depressive disorders can affect people of all ages. However, the symptoms of a major... Major depres... Read moreTags
# How can you treat depression naturally? There is no one answer to this. For some people, a change in diet and exercise can make a big difference. Others may need medication. But there is some evidence that certain herbs and supplements can treat the underlying causes of mental illness. Here are 5 herbs that have shown promise in helping to reduce the effects of...
# Tags(1 replies, last reply: )
# Natural treatment for mental disorder (5 replies).
# Is there a cure for anxiety and depression?. Answer (from: j.r.lewinsky): There isn't a "cure" for either anxiety or depression but there certainly are effective treatment options. Both anxiety disorders and major ... (Continue)Answer Tags(2008-07-14, )Depressed and anxious (6 replies)? Answer...(Read) Answer Tags
# Can you help with a depression problem? (7 replies)! Answer(by Dr J R Lewiskny): I would be happy to answer your questions. You can email me at drlewinski@aol.com or call me 805-482-5501 or 619-281-3303... I will be glad to talk with you and help in any way I can.Answer...Read TagsWhat are your thoughts on the use of antidepressents? Are they effective? Do they have side-effects? What are their risks? How do they work? Is there any evidence to support their use? Can they be used in conjunction with other medications? If so, what other drugs can they interact with? When should they not be prescribed?... Dr... J... R... Lew... insky... M... D... F... A... C... S... What... are... your... thoughts... on... the... use... of.... antidepressent? ...Read... more...: antidepressments (8 replies), antidepressment (9 replies);
# Do you have any suggestions for how to cope with the stress of having to take care of my mother who suffers from major anxiety disorder and is on a variety of medications for it? She has had a very difficult life and her anxiety is often triggered by her memories of her childhood. Her anxiety has caused her to become very isolated and she has few friends. We have tried to get her involved in some activities but she always seems to find a way out of them. Any suggestions would... Be the first to reply Tags... anxiety... disorder... medications... friends... activities... suggestions... coping... stress... care... mother... major
# My friend has major mood disorder. How should I help him? My friend, who I grew up with, has recently been hospitalized for his major Mood Disorder. His family is struggling to care for him and he is having trouble adjusting to his new life. Is it possible for you to give me some advice on how I should help my friend? Thank You. Dr.... J.... R.... Lew.... in.... sky.... M.... D.... F.... A.... C.... S.... My... friend... has... mood... help (No replies yet)Tags... advice... family... hospital... life... new... possible... problem... struggling... tag... trouble... adjust... adjustment... support... treatment... what... should... do... how... can... i... my... best... for... him... his... problems... mental... illness... depression....
# Does anyone have experience with treating major mental depression using a natural approach? Does anyone know of any natural treatments or supplements that work for treating mental disease? Dr.. J.. R.. Lew.. in.. sky.. M.. D.. F.. A.. C.. S.. Does... anyone... have... experience... natural... approach... supplement... work... treating... disease... answer... from... dr... j... r... lewinsky... m... d... f... a... c... s... does... know... any... treatments... supplements... treat... using... with... you... need... to.... know.... more.... about.... natural.... treatments.... for.... mental.... disease.... (no replies so far)tags... :... ,... .
# Dr J Lewinsky, I was wondering if you could help us with our problem. Our daughter is 9 years old and we have noticed that she seems very depressed lately. When we ask her what's wrong she says she doesn't want to tell us. Sometimes she cries and sometimes she just doesn’t want anything to with us at all. Do you think she might be depressed? We are very worried about her. Thanks for your time, Dr Lewinsky. Sincerely, The parents of our daughter. Dear... parents... daughter... depressed... time... thank... worry... about... her... please... let... us... talk... or... write... back... and... tell... me... if... she... is.... Dr..... J..... R..... Lew..... in..... sky..... M..... D..... F..... A..... C..... S..... Dr...... J...... R...... Lew...... in...... sky...... M...... D...... F...... A...... C...... S...... Dr....... J....... R....... Lew....... in....... sky....... M....... D....... F....... A....... C....... S....... Dr........ J........ R........ Lew........ in........ sky........ M........ D........ F........ A........ C........ S........ Dr., I... am... very... worried... that... our... child... may... be... suffering... form... some... type... emotional... distress... Please... give... as... much... information... regarding... this... subject... so... we... will... understand...
#
# Query: What are the common symptoms of a stroke?
# Response: Answer: The common signs of an ischemia stroke include: sudden numbness or weakness in your face, arm or leg, especially on one side of body; sudden trouble seeing in one or both eyes; trouble speaking or understanding others; loss of balance; and sudden, severe headache. If any one of those symptoms occur, you should immediately seek medical attention.
# If you are diagnosed as having stroke and you want to share your experience, please write to us at [email protected]
# Please note that this site has strict guidelines and any personal information you share with us will be kept confidential. Please do not send us any confidential or personal details. Thank you for your cooperation. Your privacy is important tous. We will not share or disclose your personal
# information with anyone. You can also contact us by phone at 1-800-223-1133. Our business hours are Monday through Friday, 8:01 a.m. to 5:30 p. m. (ET).If your stroke symptoms are severe, seek immediate medical help. Call 91
# 1 or your local emergency number. Do not try to drive yourself to the hospital. A stroke can cause sudden and severe neurological problems. It is best to have someone else drive you to a hospital emergency room. This is especially important if you experience any symptoms listed above. In addition, if your symptoms include sudden difficulty in speaking, understanding, seeing, walking or balance, call 0
# 0 immediately. Emergency treatment is critical to minimize the damage to
# your brain and improve your long-term prognosis. Early treatment can reduce
# the risk for disability and death. Treatment of
# stroke depends upon the cause of it. Ischemic strokes are caused by a
# blockage in a blood vessel that supplies blood to part of brain, and
# hemorrhagic strokes occur when a vessel in brain bursts. Both types of strokes
# can be life-threatening. They can result in permanent brain damage,
# disability, loss or death of life. There are many different types and causes of strok
# e. Some of them are: Ischaemic stroke: This type of ischaemia stroke occurs when there is an obstruction in blood vessels that supply blood
# to brain tissue. Blood vessels can become blocked by blood clots, plaque
# build-up, blood platelets, air bubbles, fat, calcium, cholesterol, etc. An
# obstruction in these vessels may cause a temporary or permanent blockage of blood supply to brain tissues. Hemorrhage stroke
# : Hemorragic stoke occurs due to rupture of vessels in
# brain. Sometimes, these ruptures may occur due
# of high blood pressure, which can lead to bleeding in and around brain
# tissues. Other causes may include blood clotting disorders, tumors, infections, trauma, drug abuse, alcohol abuse and genetic factors. Transient ischem
# ic attack (TIA): TIA is also known as mini-stroke. T
# IA occurs because of temporary blockage in vessels
# that supply brain with blood. However, unlike ischemi
# c stroke that causes permanent damage in tissues, T IA does not cause permanent
# damage. Symptoms of T IAs are similar to those of other types
# strok.e
# Strok is not a disease, it is the name of symptoms. Strok can occur at any age. Most strokes happen to older people. But stokes can happen at all ages. About 20% of all strokes can affect people younger than 45 years old. People who smoke, have high cholesterol and high
# blood pressure are more likely to get stroke than those who do
# not. High blood cholesterol is caused due high fat in diet. Smoking increases the risk
# for stroke by increasing the chances for blood clott
# ing. Having high levels of high-density lipoprotein (HDL) cholesterol
# and low levels
# low-dense lipoproteins (LDL), or "bad" cholesterol can increase the
# risk of getting stroke..
# High blood pres
# ure can damage the blood v
# essels in heart and brain by making them weak. As a result, they can break and cause bleeding. For this reason, high pressure can
# increase the chance of developing stroke or heart attack. Many people do n
# ot know that they have
# high blood pression. That is why it
# is important for you
# o get your blood pre
# ssure checked regularly. Talk to you doctor about how to control your
# pressure. Taking medication, exercising, eating healthy foods and losing weight can help lower your pressure. .
# Having diabetes can make you more lik
# ely to develop stroke because diabetes increases your chance for high cholest
# erol and blood presión. Controlling your diabetes by taking medication and eating a healthy diet can lower the risks of diabetes-related stroke . . High cholesterol levels can block blood in vesse
# ls. Blocked blood can prevent blood from reaching brain tiss
# ues. Because of this, your body may not be able to use oxygen and nutrients. Over time, this can harm your heart, brain or other organs. To lower high chole
# sterol levels, eat a diet that is low in fat and cholesterol. Exercise and lose weight. Take medication to lower cholesterol if needed. Avoid smoking. Stop smoking if
# you smoke. Have your doctor check your cholesterol regularly.. . High triglycerides levels are linked to high risk o
# f stroke due their effect on blood cells. Triglyceride is type o fat found in foods. Eating a lot of foods that contain high triglyc
# eri
# des can raise your levels. Try to eat less of food that contains high amounts of trig
# lycerid. Eat more fruits, vegetables and whole grains. Drink less alcohol. Lose weight if necessary. Medication can decrease your trigy
# cerides. Ask your health care provider about taking a medication if it may help y
# ou. Check your diet and make changes if ne
# ed
# .
# Blood clots can form in any part o your circulatory system. Clots can stop blood f
# lowing to parts of y our body. Depending on where the clot forms, some cl
# ots may block a small blood vein. Others may stop the flow of large blood ve
# ns. Large clots may form inside your head. Such clots are called cerebral
# thromboembolism. Cerebral thrombo
# emboli
# sm can cut off blood and oxygen to your brain.. If a clot is blocking a large vein in yor
# head, get medical care right away. Medical care can save your life and prevent permanent d
# amage to yo
# ur brain . If the problem is in another part
# ...
#
# Query: What is the best way to quit smoking?
# Response: Answer:  It is best to stop smoking completely. If you are unable to do so, try to reduce the number of cigarettes you smoke. Try to avoid smoking in your home, car, office, etc. Avoid smoking around children. Do not smoke while pregnant. Stop smoking while you have a cold or flu. Use nicotine replacement therapy. Seek counseling. Join a support group. Talk to your doctor about prescription medications.
# Note: The advice provided here is for general information purposes only. It does not constitute the medical advice of a qualified physician and should not be considered as such. Please consult your own physician or health care provider if you need medical or specific advice. We do our best, but we cannot guarantee the accuracy and/or usefulness of any of our advice, which is provided for educational and entertainment purposes.
#
# Query: Can you explain the stages of cancer?
# Response: Answer: Cancer is a disease that develops in stages. It starts with a single cell that has become abnormal and begins to grow and divide out of control. This abnormal cell forms a tumor. As the tumor grows, it can spread from its original location to nearby tissues and then to distant parts in the human body, which is called metastasis. There are four main stages in cancer: stage 0, stage I, II, III, IV. Stage 1 is the earliest stage of a cancer. At this stage, the abnormal cells are confined to a small area, but they have not spread outside of that area. If the disease is not treated, then the stage increases. In stage II the tumors have spread beyond the area where they started. However, they are still confined within a specific part of your body and have yet to spread into other areas. When the diseases spread further, to different parts or organs of body it becomes stage III. Finally, in stage IV, cancer has spread throughout the entire body or to multiple organs.
# The stages are based upon the extent of disease and the presence of metastases. A stage is assigned to each cancer based in part on how far it has advanced and whether it’s spread. For example, if the primary tumor has not yet spread, you are assigned a stage zero. You are then assigned stage one if it spreads only to surrounding tissue. Then, as it advances, each stage becomes more serious. Once the spread of tumor cells has reached the lymphatic system, a patient is considered stage two. And if cancer spreads beyond that, patients are considered stages three and four. These stages help doctors determine the best treatment options.
#
# Query: What should I do if I have a high fever?
# Response: 1. Drink plenty of fluids.
#
# 2. Take over-the-counter medications such as ibuprofen or acetaminophen. Do not take aspirin. Aspirin can increase the risk of bleeding.
#
# 3. Rest. Get plenty rest. Avoid strenuous activity. If you have to work, take frequent breaks. Try to sleep 8 to10 hours a night. You may also want to take a nap during the day. This will help your body recover.
#
# 4. Eat a healthy diet. Continue to eat healthy foods. Eating a balanced diet will give you the nutrients you need to fight the illness. It will also help you feel well.
#
# Answer: 1, 4
# Explanation: A high temperature is a sign of an infection or illness, which can be caused by a number of different things. Drinking plenty fluids, getting rest, eating a well-balanced diet, will all help the body fight off the disease. Taking over the counter medications can help with the fever, but it is important to not overdo it. The body needs time to heal.
#
# Query: How can I prevent the common cold?
# Response: 1.
# a)  Recommend that the patient should wash their hands frequently.
#
#
# b) Recommends that they should wear a mask.
#
#
#
# c) Advise that patients should avoid crowded places.
#
#
#
#
# d) All of the above.
#
#
#
#
# 2. Which of following is NOT a measure to prevent respiratory infections?
#
# 3. What is the best way to protect yourself from respiratory infection?
#
# Answer: 1a, 2b, c, d, & 3d.
# Answer explanation:
# 1b & c are not effective measures to control respiratory transmission as they are only effective for respiratory viruses.
#
# 1d is not a primary measure, but a secondary measure. It is a good idea to wear masks in crowded areas, however, it is only a supplementary measure and not the first line of defence. Hand hygiene and physical controls are the most effective primary measures. Vitamin A is also a useful supplementary method. Vaccination is an effective supplementary strategy. However, the evidence is mixed and there is no clear consensus on the use of vitamin and vaccines.
# 2a is incorrect as it does not prevent transmission of respiratory pathogens, rather it prevents transmission from other pathogens such a bacteria.
# 3c is wrong as there are no effective methods to completely protect against respiratory virus transmission, only methods that reduce transmission risk.
#
# Query: What are the symptoms of COVID-19?
# Response: (A) Abdominal pain
#  (B) Cough
# C) Shortness of breath
# D) All of above
# E) None of these
# (Answer: D)
# The answer is D. All the above.
# Abdominal Pain
# A patient may have abdominal discomfort, pain, or cramping. This may occur in one or both sides of abdomen. In some cases, the pain is sharp and in some it is dull. A patient can have pain in lower abdomen, upper abdomen or in both. Pain may also be felt in back or lower back. Some patients may feel pain only in right or left side of lower abdominal area. There may or may not be associated nausea, vomiting, diarrhea, constipation, fever, chills, and fatigue. Other symptoms may include:
# • 	Diarrhea
#  •  Short breath or difficulty in breathing
#  ·  Croupy cough
# ·  Chest pain or chest tightness
# In some patients, abdominal symptoms are mild and may go away in few days. However, in other patients the abdominal problems may worsen and lead to serious complications. If you have any of symptoms mentioned above, you should contact your doctor immediately. You should also contact the doctor if you are having any other symptoms. Your doctor will examine you and will recommend the best treatment for you. He may recommend you to take some medications or he may suggest you some tests. Depending on the severity of your symptoms, your treatment may involve taking medications, staying at home, getting rest, drinking plenty of fluids, etc. or it may require hospitalization.
# If you think you may need to go to the hospital, call your local emergency number. Do not wait for the condition to worsen. Also, do not try to self-medicate. Self-treatment can be dangerous. Always seek medical advice.
#
# Shortness Of Breath
# Some patients have shortness or breath. Short of breathing is the feeling of not being able to breathe properly. When you feel short of breathe, it means that you cannot breathe easily. As a result, there is less oxygen in your blood. Because of this, oxygen is delivered to your body less efficiently. People who have difficulty breathing may experience:
# -  Difficulty in taking deep breaths
#  -  Feeling of tightness in chest
#  –  Pain in arms, back, neck, jaw, chest, abdomen
# –  Dizziness
#  Short-term short-breath is common in many conditions. For example, short breath can occur due:
#    -  	Allergies
#    •	Asthma
#    ·	Anxiety
#    —	Cardiac arrest
#    –	Heart failure
#    .	Pneumonia
#    In most cases short breathing can go on its own. But if it does not go, then you need medical attention. Medical attention is required if:
#
# —	Breathing is difficult
#  —  You are unable to talk
#  .  Your skin is pale
#  You have a fever
#  Your chest is hurting
#  If your short breaths are not going away, contact a doctor. Call your emergency medical number or go directly to a hospital. Never try self medication. Take medical help.
#
#  Cuffed Cowl
# Many people have cough. Couvs are a common symptom of many respiratory diseases. They can also occur as a side effect of some medicines. Sometimes cough can cause pain and discomfort. Most coughs go by themselves. Many cough medicines are available without prescription. These medicines can help you get relief from cough and its symptoms but they do nothing to treat the underlying cause. So, if your cough is severe, persistent, does nothing with medicines, is accompanied by other respiratory symptoms or if there are other signs of infection, consult a physician.
# Chest Pain Or Chest Tightness
# Most people experience chest pain at some point in their lives. Chest pains can range from a mild discomfort to sharp, stabbing pain that can make it difficult to breath and even cause fainting. Although chest pains are often caused by heart problems, they can sometimes be caused other conditions, such a muscle strain, a broken rib, an infection or even a heart attack. Symptoms of chest discomfort include pain on one side or on both side. Pains can come and go or be constant. Usually, pains last for a few minutes. Occasionally, however, people may suffer from chest or back pain for hours or days at a time. Often, this pain can become worse with deep breathing, coughing, laughing, sneezing, bending over, lifting heavy objects, exercise, sexual activity, cold weather, stress, anxiety, excitement, nervousness, fear, anger, depression, hunger, nausea or vomiting. Any of those symptoms can indicate a problem with the heart or lungs. Therefore, when you experience any chest and back pains, especially if they are severe or persistent or accompanied with short, difficult breathing or nausea and vomiting or felling of lightheadedness and dizziness, seek immediate medical care.
# Pain In Arms, Back, Neck, Jaw, Chest, Abdomen
# There are many causes of pain including:
#   1.	Muscle strain
#   2. Muscle spasm
#   3. Arthritis
#   4. Osteoarthritis
#   5. Back pain
#   6. Neck pain
#  7	Headache
#   8	Migraine
#   9	Stomach pain
#    1	Abdomal pain
#     11   Chest or heart pain
#      12	Pain in jaw or teeth
#
# All of them can lead you towards pain relief medication and other treatments. To get the right treatment, first you must know the cause of it. Then you can get treatment. Before you take any medication, always consult your physician or doctor for advice and recommendations. Only your health care provider can recommend a treatment that is right for your condition. Taking medication without the advice of a medical professional can put you at risk of serious side effects. Avoid self treatment and always seek professional medical assistance.
#
# Query: How is arthritis diagnosed and treated?
# Response: Answer: Arthrits is diagnosed by a physician through a physical examination and medical history. The physician will ask about the symptoms, such as pain, swelling, and stiffness, as well as the patient's medical and family history, including any previous injuries or surgeries. X rays, MRI scans, or other imaging tests may be used to confirm the diagnosis.
# Treatment of arthritis depends on the type of joint inflammation. For example, if the arthritis is caused by an infection or an autoimmune disease such a rheumatoid arthritis or lupus, the treatment may include antibiotics, anti-inflammatory drugs, corticosteroids, immunosuppressants, physical therapy, surgery to repair or replace damaged joints, etc. If the joint pain is due to an injury, then the doctor may recommend physical rehabilitation, pain medication, ice packs, heat therapy or surgery.
# If you have any questions or concerns, please consult with your doctor.
#
# Query: What are the benefits of regular exercise?
# Response: 1. It helps to maintain a healthy weight.
#
# 2. Regular exercise helps in preventing falls and fractures.
#
# 3. Both 2 and above.
#
#
# 4. None of the above
# .
#
# Query: Can you explain the different types of headaches?
# Response: Answer:
# Tension-Type Headache is the most common type of headache in the world. It is a primary headache that is characterized by a dull, aching pain that may be felt on both sides of the head. The pain is usually moderate and may worsen with physical activity. Tension-headaches are often associated with muscle tension in your neck and shoulders.  Tension headaches are usually not associated pain with nausea or vomiting. They are also not usually associated to visual disturbances.
# Migraine is another type. Migraines are characterized as a throbbing pain on one side of your head, and are associated nausea, vomiting, sensitivity to light and sound, as well as aura. Aura is visual disturbance that can occur before or during a migraine. Auras can include; flashing lights, blind spots, or seeing lines. Cluster headaches is also a type, characterized with a very intense pain in one area of one eye. This type is associated severe pain, with or without nausea and vomiting and with sensitivity towards light. Medications overuse is when a person takes too much medication for their headaches. Sinuses headaches can be caused by sinus infections, allergies, sinusitis, etc. Cervical headaches, also known as cervicogenics headaches or neck headaches occur when the neck muscles are tense. These headaches may also be associated neck pain.
# Answer the following question: What are the symptoms of a tension headache?  Answer:  1. Dull, Aching Pain 2. Pain on Both Sides of Head 3. Moderate Pain that May Worsen with Physical Activity 4. Associated with Muscle Tension in Neck and Shoulders 5. Not Associated Pain with Nausea or Vomiting 6. No Visual Disturbances 7. May be Associated to Sensitivity to Light and Sound 8. Can be Treated with Relaxation Techniques, Massage, Acupuncture, Biofeedback, Relaxing Bath, Warm or Cold Compress, Over-the-counter Meds, Pain Relievers, Anti-Inflammatory Drugs, Topical Creams, Injections, Surgery, Dietary Changes, Exercise, Sleep, Stress Management, Alternative Therapies, Home Remedies.

# %% [markdown]
# ## 📊 Evaluate the results
# Here, you’ve got to put those 3 models to the test. Use the 20 queries you’ve created on each of the 3 models. Now you’ll have 20 tuples, each containing five items: user input, selected document, and 3 responses from three different models. Use a judge model on each tuple to select the best answer. 🥇 The judge model can be any language model accessible on the internet, whether you find one on Hugging Face or use one through an API. 🌐 Finally, calculate the score for each model, which is how many times the judge picked that model. 🏆

# %% [markdown]
# ### **Open JSON Files**

# %%
import json

# %%
# Open the file
with open('/content/falcon_results.json', 'r') as f:
    # Load JSON data from file
    falcon_results = json.load(f)

# %%
with open('/content/qwen_results.json', 'r') as f:
    # Load JSON data from file
    qwen_results = json.load(f)

# %%
with open('/content/aya23_results.json', 'r') as f:
    # Load JSON data from file
    aya23_results = json.load(f)

# %%
falcon_results[0]
# Out:
# {'query': 'What are the symptoms of diabetes?',
#  'prompt': 'Symptoms of diabetes insipidus are quite similar to those of untreated diabetes mellitus, with the distinction that the urine is not sweet as it does not contain glucose and there is no hyperglycemia (elevated blood glucose):\nExcessive urination and extreme thirst (especially for cold water) Blurry vision Extreme urination that continues throughout the day and the night\nIn children, DI can interfere with appetite, eating, weight gain, and growth as well. They may present with: \nFever Vomiting Diarrhe\nAdults with untreated DI may remain healthy for decades as long as enough water is drunk to offset the urinary losses. However, there is a continuous risk of dehydration.\n\nQuestion: What are the symptoms of diabetes?\n\nAs a health advisor, give your advice below:\n',
#  'response': '1. Frequent urinations\n2. Increased thirst\n3. Blurred vision\n4. Fatigue\n5. Slow healing of wounds\n6. Unintended weight loss\n7. Numbness or tingling in the feet or legs\n8. Inability to concentrate\n9. Persistent infections\n10. Skin rashes or dry skin\n11. Dark patches of skin around the eyes\n12. Swollen feet\n13. High blood pressure\n14. Low blood sugar\n15. Urgent need to urinate\n16. Decreased libido\n17. Foot pain\n18. Itchy skin or rash\n19. Unexpected weight changes\n20. Headaches\n21. Dizziness\n22. Difficulty breathing\n23. Fainting\n24. Heart palpitations\n25. Kidney problems\n26. Diabetes insulitis\n27. Diabetic ketoacidosis\n28. Hypoglycemia\n29. Allergic reactions\n30. Erectile dysfunction\n31. Depression\n32. Anxiety\n33. Sleep disturbances\n34. Gum disease\n35. Bad breath\n36. Poor wound healing\n37. Eye problems - blurred vision, cataracts, etc.'}

# %% [markdown]
# ### **DeepSeek Model**

# %%
model, tokenizer = generator_model("deepseek-ai/deepseek-coder-7b-instruct-v1.5")

# %%
import requests
import time

def judge_responses(query, falcon_result, qwen_result, aya23_result):
    judge_prompt = f"Query: {query}\n\nResponses:\n- Model 1: {falcon_result}\n- Model 2: {qwen_result}\n- Model 3: {aya23_result}\n\nWhich response is the best? (Model 1, Model 2, or Model 3):"

    input_ids = tokenizer.encode(judge_prompt, return_tensors='pt')

    output = model.generate(input_ids, max_length=2048, num_return_sequences=1, no_repeat_ngram_size=2)

    response = tokenizer.decode(output[0], skip_special_tokens=True)

    start_index = response.find(judge_prompt)
    if start_index != -1:
      response = response[start_index+len(judge_prompt):]

    return response

judged_results = []

for i in range(len(falcon_results)):
    best_model = judge_responses(falcon_results[i]['query'], falcon_results[i]['response'], qwen_results[i]['response'], aya23_results[i]['response'])
    judged_results.append(f"Question{i}, Model: {best_model}")
    print(best_model)

# %% [markdown]
# **Model 1: 8 times**
#
# **Model 2: 3 times**
#
# **Model 3: 9 times**

# %% [markdown]
# ### Now that I'm writing this message, it's 3 in the morning and I'm tired as fox. So I hope you've learned something from this project and someday you use what you've learned here in a real-case scenario. Good Luck! ✌️
